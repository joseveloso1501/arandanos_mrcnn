# %% [markdown]
# # Test 11 (paper) - Experimento 7 (PT)
#
# Entrenamiento de Mask R-CNN con dataset modificado para emular "Test 11"
#
# ### Hiperparametros
# * **epoch = 100**
#     * steps x epoch = 146 (lotes de imagenes)
#     * batch = 2
# * optimizador = SGD
# * Funcion de perdida = SMOOTHL1LOSS
# * Metrica de evaluacion = mAP (IoU >= 0.5)
# * **Mini-mask shape: 28x28**
# * **RPN anchor scales: (8, 16, 32, 64, 128)**
# * Tasa de aprendizaje: 0.001
# * **imagenes = 305**
#     * entrenamiento 70% = 177
#     * validacion 30% = 128
# * etiquetas = 9140
# * **resolucion = 1920 x 1080**
# * etiquetas = bounding box formato VOC XML
# * **numero de clases = 2 (arandano, arandano-maduro)**
# * **data augmentation = false**

# %% [markdown]
# ## Comprobar directorio principal

# %%
# !pwd && ls -l
# Out:
# /tf/PT_JoseVeloso/Mask_RCNN-master_matterport/model-training
# total 1480
# drwxr-xr-x 4 root root   4096 Aug  7 06:10 build
# drwxr-xr-x 2 root root   4096 Aug  7 06:10 dist
# drwxr-xr-x 2 root root   4096 Aug  8 03:15 mask_rcnn.egg-info
# -rw-r--r-- 1 root root  67672 Sep 16 23:44 master-test_11.ipynb
# -rw-r--r-- 1 root root  39459 Sep 16 23:53 master-test_11_fase_2-Copy1.ipynb
# -rw-r--r-- 1 root root  67672 Sep 16 23:48 master-test_11_fase_2.ipynb
# -rw-r--r-- 1 root root  30144 Sep 16 23:44 master-test_12.ipynb
# -rw-r--r-- 1 root root  30144 Sep 16 22:02 master-test_12_fase_2.ipynb
# -rw-r--r-- 1 root root 350337 Sep 15 00:38 master-test_5-fase_2.ipynb
# -rw-r--r-- 1 root root 162983 Sep 15 02:23 master-test_5.ipynb
# -rw-r--r-- 1 root root 350111 Sep 15 02:26 master-test_5_fase_2.ipynb
# -rw-r--r-- 1 root root 110254 Sep 15 02:25 master-test_6.ipynb
# -rw-r--r-- 1 root root 270148 Sep 15 15:04 master-test_6_fase_2.ipynb
# drwxr-xr-x 4 root root   4096 Sep 13 07:49 mrcnn
# drwxr-xr-x 3 root root   4096 Sep 15 02:27 old

# %% [markdown]
# # Importar bibliotecas

# %%
# bibliotecas basicas
import os
from os import listdir
import sys
import json
import datetime

#sys.path.append("/tf/PT_JoseVeloso/Mask_RCNN-master/")

# bibliotecas avanzadas 
from xml.etree import ElementTree
import skimage.draw
import cv2
import imgaug

# bibliotecas mask rcnn 
from mrcnn.utils import Dataset
from mrcnn.config import Config
from mrcnn.model import MaskRCNN
from mrcnn.visualize import display_instances
from mrcnn.utils import extract_bboxes
from mrcnn.utils import compute_ap
from mrcnn.model import load_image_gt
from mrcnn.model import mold_image
from mrcnn import visualize

# biblioteca matplotlib 
import matplotlib.pyplot as plt

# bibliotecas numpy 
import numpy as np
from numpy import zeros
from numpy import asarray
from numpy import expand_dims
from numpy import mean

# bibliotecas keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img   #keras.preprocessing.image tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

# ignorar alertas de elementos que seran descontinuados
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

# %matplotlib inline
#plt.show()

import imgaug.augmenters as iaa

# %% [markdown]
# # Fase 2 - Entrenamiento con dos clases y etiquetas de Bounding Box

# %% [markdown]
# En este entremamiento se utiliza un conjunto de datos simple con imágenes etiquetadas con cuadros delimitadores y una clase llamada 'Daño'. En la siguiente sección se encuentra el código para el entrenamiento del modelo. Se incluyen comentarios para describir mejor el flujo del programa.

# %%
class DatasetArandanos(Dataset):
    
    # la funcion load_dataset es usada para cargar el dataset de entrenamiento y test
    def load_dataset(self, dataset_dir, is_train=True):
        
        # se agrega una clase que se necesita para clasificar, en este caso arandano
        self.add_class("dataset", 1, "arandano")
        
        # se concatena dataset_dir con /images y /annots
        images_dir = dataset_dir + '/images/'
        annotations_dir = dataset_dir + '/annots/'
        
        # is_train sera Verdadero si se esta entrenando el modelo y Falso si se esta testeando el modelo
        for filename in listdir(images_dir):
            
            # extraer image id
            image_id = filename[:-4] # se usa para omitir los últimos 4 caracteres: '.jpg' (en class_id.jpg)
            
            # si is_train es Verdadero se omiten todas las imágenes con id mayor que e iguales a 11074
            # aproximadamente el 80% del conjunto de datos es para entrenamiento
            
            if is_train and int(image_id) >= 11074 :
                print("image_id: ", image_id)
                continue
            
            # si is_train no es Verdadero se omiten todas las imágenes con id menores a 11074
            if not is_train and int(image_id) < 11074:
                continue
            
            # se declara la ruta de la imagen y la ruta de las etiquetas 
            img_path = images_dir + filename
            ann_path = annotations_dir + image_id + '.xml'
            
            # usando la función add_image se pasan image_id, image_path y ann_path para que la 
            # imagen actual se agregue al conjunto de datos para entrenamiento o prueba
            self.add_image('dataset', image_id=image_id, path=img_path, annotation=ann_path)

    # funcino usada para extraer bouding boxes desde archivos etiquetados 
    def extract_boxes(self, filename):

        # se puede ver en las imágenes que estan etiquetadas, como se extraen los valores de ancho, alto y bndbox
        
        # <annotation>
        # <size>

        #       <width>640</width>

        #       <height>360</height>

        #       <depth>3</depth>

        # </size>


        # <object>

        #          <name>damage</name>

        #          <pose>Unspecified</pose>

        #          <truncated>0</truncated>

        #          <difficult>0</difficult>


        #          <bndbox>

        #                 <xmin>315</xmin>

        #                 <ymin>160</ymin>

        #                 <xmax>381</xmax>

        #                 <ymax>199</ymax>

        #          </bndbox>

        # </object>
        # </annotation>
        
        # para analizar los archivos .xml
        tree = ElementTree.parse(filename)
        
        # para obtener la raíz del archivo xml
        root = tree.getroot()
        
        # se agregan todas las coordenadas x, y en boxes para todas las instancias de un objeto
        boxes = list()
        
        # se encuentran todos los atributos con el nombre bndbox que existan para cada ground truth en la imagen
        for box in root.findall('.//bndbox'):
            xmin = int(box.find('xmin').text)
            ymin = int(box.find('ymin').text)
            xmax = int(box.find('xmax').text)
            ymax = int(box.find('ymax').text)
            coors = [xmin, ymin, xmax, ymax]
            boxes.append(coors)
        
        # extraer ancho y alto de la imagen
        width = int(root.find('.//size/width').text)
        height = int(root.find('.//size/height').text)
        
        # retorna boxes-> list, width-> int y height-> int 
        return boxes, width, height
    
    # this function calls on the extract_boxes method and is used to load a mask for each instance in an image
    # returns a boolean mask with following dimensions width * height * instances

    # esta función llama al método extract_boxes y se usa para cargar una máscara para cada instancia en una imagen 
    # devuelve una máscara booleana con las siguientes dimensiones ancho * alto * instancias
    def load_mask(self, image_id):
        
        # info apunta al image_id actual 
        info = self.image_info[image_id]
        
        # se obtiene la ruta de anotación de image_id que es dataset_dir/annots/image_id.xml 
        path = info['annotation']
        
        # se llama al método extract_boxes (arriba) para obtener bndbox del archivo .xml
        boxes, w, h = self.extract_boxes(path)
        
        # se crea una cantidad de len(boxes) de mascaras de alto 'h' y ancho 'w'
        masks = zeros([h, w, len(boxes)], dtype='uint8')
        
        # se agrega (append) el class_id 1 para arandano en nuestro caso a la variable
        class_ids = list()
        
        # se recorren todos los boxes y generamos máscaras (máscara de bndbox) y class id para cada instancia
        # las máscaras tendrán forma rectangular ya que hemos usado bndboxes para etiquetas
        # por ejemplo: si 2.jpg tiene tres objetos, tendremos las siguientes máscaras y class_ids.

        # 000000000 000000000 000001110 
        # 000011100 011100000 000001110
        # 000011100 011100000 000001110
        # 000000000 011100000 000000000
        #    1         1          1    <- class_ids
        for i in range(len(boxes)):
            box = boxes[i]
            row_s, row_e = box[1], box[3]
            col_s, col_e = box[0], box[2]
            masks[row_s:row_e, col_s:col_e, i] = 1
            class_ids.append(self.class_names.index('arandano'))
        
        # retorna mascaras y class_ids como arreglo
        return masks, asarray(class_ids, dtype='int32')
    
    # esta funciones toma el image_id y retorna la ruta de la imagen 
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

# %%
# damage configuration class, you can change values of hyper parameters here
class ConfigArandanos(Config):

    # nombre de la configuracion
    NAME = "arandano_cfg_test_11_fase_2_"    
    
    # clase arandano + clase background + 4 clases
    NUM_CLASSES = 1 + 1
    
    # pasos por epoch y confianza minima    # STEPS_PER_EPOCH = cantidad de lotes/batchs
    STEPS_PER_EPOCH = 152  

    # tasa de aprendizaje y momentum
    LEARNING_RATE=0.001
    LEARNING_MOMENTUM = 0.8
    
    # penalización de regularización
    WEIGHT_DECAY = 0.0001
    
    # el tamaño de la imagen está controlado por este parámetro
    IMAGE_MIN_DIM = 512
    
    # pasos de validación
    VALIDATION_STEPS = 50
    
    # número de regiones de interés generadas por imagen
    Train_ROIs_Per_Image = 200
    
    # escala de anclas RPN y proporciones (ratios) para encontrar la ROI
    RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128)    # Longitud del lado del ancla cuadrada, en píxeles 
    RPN_ANCHOR_RATIOS = [0.5, 1, 1.5]   # Proporciones de anclas por cada celda (ancho/alto). Un valor de 1 representa un ancla cuadrada y 0,5 es un ancla ancha 

    #DEVICE = "/cpu:0"  # /cpu:0 or /gpu:0    
    DEVICE = "/gpu:0"  # /cpu:0 or /gpu:0

    IMAGES_PER_GPU = 2
    
    MINI_MASK_SHAPE = (28, 28)
    
ConfigArandanos().display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# DEVICE                         /gpu:0
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.8
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (28, 28)
# NAME                           arandano_cfg_test_11_fase_2_
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 1.5]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                152
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# Train_ROIs_Per_Image           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ### Entrenamiento

# %%
cd /tf/PT_JoseVeloso/Mask_RCNN-master_matterport/
# Out:
# /tf/PT_JoseVeloso/Mask_RCNN-master_matterport

# %%
#pesos = 'mask_rcnn_coco.h5'
#pesos = 'mask_rcnn_damage_cfg_0049.h5'
#pesos = 'arandano_cfg_test_5_20220907T0914/mask_rcnn_arandano_cfg_0300.h5'
#pesos = 'arandano_cfg_test_5_20220907T0914/mask_rcnn_arandano_cfg_0300.h5'
pesos = 'arandano_cfg_test_5_fase_2_20220913T0749/mask_rcnn_arandano_cfg_test_5_fase_2__0300.h5'

conjunto_datos = 'customImages/test_11_fase_2'

# %%
# cargar dataset de entrenamiento
train_set = DatasetArandanos()
train_set.load_dataset(conjunto_datos, is_train=True)
train_set.prepare()

# cargar dataset de test 
test_set = DatasetArandanos()
test_set.load_dataset(conjunto_datos, is_train=False)
test_set.prepare()

# preparar la configuración llamando a la clase de configuración definida por el usuario
config = ConfigArandanos()

# definir el modelo
with tf.device(config.DEVICE):
    model = MaskRCNN(mode='training', model_dir='./', config=config)

# cargar pesos del modelo 
weights_path = pesos

# cargar los pesos del modelo
model.load_weights(weights_path, 
                   by_name=True, 
                   exclude=["mrcnn_class_logits", "mrcnn_bbox_fc",  "mrcnn_bbox", "mrcnn_mask"])

#augmentation = iaa.Sequential(iaa.Fliplr(0.5), iaa.Flipud(0.5))
#augmentation = iaa.Sometimes(5/6,iaa.Fliplr(0.5), iaa.Flipud(0.5))
#augmentation = iaa.Sequential([iaa.Fliplr(0.5), iaa.Flipud(0.5)])
#augmentation = iaa.Sometimes(5/6, iaa.Fliplr(0.5), iaa.Flipud(0.5))
#augmentation = iaa.Sometimes(0.5, iaa.Fliplr(0.5), iaa.Flipud(0.5))

# start the training of model
# you can change epochs and layers (head or all)
#model.train(train_set, test_set, learning_rate=config.LEARNING_RATE, epochs=100, layers='all', augmentation=augmentation)
model.train(train_set, test_set, learning_rate=config.LEARNING_RATE, epochs=100, layers='all')
# Out:
# image_id:  31102
# image_id:  40099
# image_id:  51320
# image_id:  30377
# image_id:  40414
# image_id:  21130
# image_id:  51422
# image_id:  50469
# image_id:  41732
# image_id:  25544
# image_id:  50458
# image_id:  23863
# image_id:  30990
# image_id:  30470
# image_id:  20318
# image_id:  50440
# image_id:  21295
# image_id:  22345
# image_id:  40390
# image_id:  51286
# image_id:  20782
# image_id:  30676
# image_id:  30000
# image_id:  50135
# image_id:  50912
# image_id:  22783
# image_id:  20150
# image_id:  40346
# image_id:  31246
# image_id:  25750
# image_id:  50983
# image_id:  50607
# image_id:  25690
# image_id:  51398
# image_id:  40999
# image_id:  21150
# image_id:  23719
# image_id:  11117
# image_id:  20425
# image_id:  40253
# image_id:  51082
# image_id:  20250
# image_id:  41406
# image_id:  20585
# image_id:  11076
# image_id:  50393
# image_id:  30851
# image_id:  50958
# image_id:  50857
# image_id:  25640
# image_id:  51057
# image_id:  50710
# image_id:  31284
# image_id:  40213
# image_id:  40960
# image_id:  50386
# image_id:  41762
# image_id:  41383
# image_id:  22536
# image_id:  30502
# image_id:  50269
# image_id:  30958
# image_id:  51341
# image_id:  22218
# image_id:  11081
# image_id:  41535
# image_id:  40393
# image_id:  25808
# image_id:  40299
# image_id:  11077
# image_id:  25817
# image_id:  25555
# image_id:  30641
# image_id:  21680
# image_id:  31040

# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/100
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/sub:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/GatherV2_2:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/Shape:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/sub_1:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/GatherV2_5:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/Shape_1:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/sub_2:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/GatherV2_8:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/sub_3:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/GatherV2_11:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_mask_1/concat_grad/sub:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_mask_1/concat_grad/GatherV2_2:0", shape=(None, 14, 14, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_mask_1/concat_grad/Shape:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_mask_1/concat_grad/sub_1:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_mask_1/concat_grad/GatherV2_5:0", shape=(None, 14, 14, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_mask_1/concat_grad/Shape_1:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/ROI_1/GatherV2_2_grad/Reshape_1:0", shape=(6000,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/ROI_1/GatherV2_2_grad/Reshape:0", shape=(6000, 4), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/ROI_1/GatherV2_2_grad/Cast:0", shape=(2,), dtype=int32, device=/device:GPU:0))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/ROI_1/GatherV2_3_grad/Reshape_1:0", shape=(6000,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/ROI_1/GatherV2_3_grad/Reshape:0", shape=(6000, 4), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/ROI_1/GatherV2_3_grad/Cast:0", shape=(2,), dtype=int32, device=/device:GPU:0))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# 152/152 [==============================] - 362s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 2.8189 - rpn_class_loss: 0.4037 - rpn_bbox_loss: 1.1469 - mrcnn_class_loss: 0.1583 - mrcnn_bbox_loss: 0.6629 - mrcnn_mask_loss: 0.4471 - val_loss: 2.1843 - val_rpn_class_loss: 0.1794 - val_rpn_bbox_loss: 0.7007 - val_mrcnn_class_loss: 0.1927 - val_mrcnn_bbox_loss: 0.6450 - val_mrcnn_mask_loss: 0.4665
# Epoch 2/100
# 152/152 [==============================] - 265s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 1.4478 - rpn_class_loss: 0.0600 - rpn_bbox_loss: 0.4664 - mrcnn_class_loss: 0.1731 - mrcnn_bbox_loss: 0.3132 - mrcnn_mask_loss: 0.4350 - val_loss: 2.0130 - val_rpn_class_loss: 0.1438 - val_rpn_bbox_loss: 0.6978 - val_mrcnn_class_loss: 0.2095 - val_mrcnn_bbox_loss: 0.5077 - val_mrcnn_mask_loss: 0.4542
# Epoch 3/100
# 152/152 [==============================] - 273s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 1.1738 - rpn_class_loss: 0.0447 - rpn_bbox_loss: 0.2904 - mrcnn_class_loss: 0.1796 - mrcnn_bbox_loss: 0.2464 - mrcnn_mask_loss: 0.4127 - val_loss: 2.0326 - val_rpn_class_loss: 0.2015 - val_rpn_bbox_loss: 0.7139 - val_mrcnn_class_loss: 0.2343 - val_mrcnn_bbox_loss: 0.4535 - val_mrcnn_mask_loss: 0.4295
# Epoch 4/100
# 152/152 [==============================] - 275s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 1.0084 - rpn_class_loss: 0.0402 - rpn_bbox_loss: 0.1921 - mrcnn_class_loss: 0.1681 - mrcnn_bbox_loss: 0.2138 - mrcnn_mask_loss: 0.3942 - val_loss: 2.1427 - val_rpn_class_loss: 0.2352 - val_rpn_bbox_loss: 0.7160 - val_mrcnn_class_loss: 0.3330 - val_mrcnn_bbox_loss: 0.4411 - val_mrcnn_mask_loss: 0.4174
# Epoch 5/100
# 152/152 [==============================] - 266s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0
 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.4351 - rpn_class_loss: 0.0149 - rpn_bbox_loss: 0.0267 - mrcnn_class_loss: 0.0522 - mrcnn_bbox_loss: 0.0577 - mrcnn_mask_loss: 0.2835 - val_loss: 2.4169 - val_rpn_class_loss: 0.2214 - val_rpn_bbox_loss: 0.8071 - val_mrcnn_class_loss: 0.5285 - val_mrcnn_bbox_loss: 0.4366 - val_mrcnn_mask_loss: 0.4234
# Epoch 19/100
# 152/152 [==============================] - 262s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.4334 - rpn_class_loss: 0.0119 - rpn_bbox_loss: 0.0297 - mrcnn_class_loss: 0.0476 - mrcnn_bbox_loss: 0.0610 - mrcnn_mask_loss: 0.2832 - val_loss: 2.7318 - val_rpn_class_loss: 0.3313 - val_rpn_bbox_loss: 0.8302 - val_mrcnn_class_loss: 0.6574 - val_mrcnn_bbox_loss: 0.4460 - val_mrcnn_mask_loss: 0.4669
# Epoch 20/100
# 152/152 [==============================] - 264s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.4149 - rpn_class_loss: 0.0127 - rpn_bbox_loss: 0.0281 - mrcnn_class_loss: 0.0454 - mrcnn_bbox_loss: 0.0536 - mrcnn_mask_loss: 0.2750 - val_loss: 2.4623 - val_rpn_class_loss: 0.2593 - val_rpn_bbox_loss: 0.7998 - val_mrcnn_class_loss: 0.5535 - val_mrcnn_bbox_loss: 0.4237 - val_mrcnn_mask_loss: 0.4260
# Epoch 21/100
# 152/152 [==============================] - 264s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.3928 - rpn_class_loss: 0.0109 - rpn_bbox_loss: 0.0222 - mrcnn_class_loss: 0.0433 - mrcnn_bbox_loss: 0.0492 - mrcnn_mask_loss: 0.2672 - val_loss: 2.9538 - val_rpn_class_loss: 0.3520 - val_rpn_bbox_loss: 0.8749 - val_mrcnn_class_loss: 0.8189 - val_mrcnn_bbox_loss: 0.4444 - val_mrcnn_mask_loss: 0.4636
# Epoch 22/100
# 152/152 [==============================] - 256s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.3753 - rpn_class_loss: 0.0098 - rpn_bbox_loss: 0.0211 - mrcnn_class_loss: 0.0412 - mrcnn_bbox_loss: 0.0465 - mrcnn_mask_loss: 0.2567 - val_loss: 2.8535 - val_rpn_class_loss: 0.2979 - val_rpn_bbox_loss: 0.8394 - val_mrcnn_class_loss: 0.7112 - val_mrcnn_bbox_loss: 0.4392 - val_mrcnn_mask_loss: 0.5658
# Epoch 23/100
# 152/152 [==============================] - 246s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.3652 - rpn_class_loss: 0.0101 - rpn_bbox_loss: 0.0219 - mrcnn_class_loss: 0.0368 - mrcnn_bbox_loss: 0.0447 - mrcnn_mask_loss: 0.2517 - val_loss: 2.4189 - val_rpn_class_loss: 0.1957 - val_rpn_bbox_loss: 0.7135 - val_mrcnn_class_loss: 0.6317 - val_mrcnn_bbox_loss: 0.4223 - val_mrcnn_mask_loss: 0.4556
# Epoch 24/100
# 152/152 [==============================] - 253s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.3556 - rpn_class_loss: 0.0098 - rpn_bbox_loss: 0.0225 - mrcnn_class_loss: 0.0354 - mrcnn_bbox_loss: 0.0439 - mrcnn_mask_loss: 0.2441 - val_loss: 3.0546 - val_rpn_class_loss: 0.3541 - val_rpn_bbox_loss: 0.8819 - val_mrcnn_class_loss: 0.8330 - val_mrcnn_bbox_loss: 0.4568 - val_mrcnn_mask_loss: 0.5287
# Epoch 25/100
# 152/152 [==============================] - 277s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.3524 - rpn_class_loss: 0.0099 - rpn_bbox_loss: 0
 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.2755 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.0165 - mrcnn_class_loss: 0.0251 - mrcnn_bbox_loss: 0.0315 - mrcnn_mask_loss: 0.1958 - val_loss: 3.0431 - val_rpn_class_loss: 0.4508 - val_rpn_bbox_loss: 0.9057 - val_mrcnn_class_loss: 0.7602 - val_mrcnn_bbox_loss: 0.4128 - val_mrcnn_mask_loss: 0.5136
# Epoch 33/100
# 152/152 [==============================] - 263s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.2729 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.0180 - mrcnn_class_loss: 0.0251 - mrcnn_bbox_loss: 0.0301 - mrcnn_mask_loss: 0.1922 - val_loss: 3.3107 - val_rpn_class_loss: 0.3830 - val_rpn_bbox_loss: 0.8630 - val_mrcnn_class_loss: 0.9293 - val_mrcnn_bbox_loss: 0.4558 - val_mrcnn_mask_loss: 0.6796
# Epoch 34/100
# 152/152 [==============================] - 262s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.2645 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.0160 - mrcnn_class_loss: 0.0231 - mrcnn_bbox_loss: 0.0293 - mrcnn_mask_loss: 0.1887 - val_loss: 3.0606 - val_rpn_class_loss: 0.4247 - val_rpn_bbox_loss: 0.9073 - val_mrcnn_class_loss: 0.7763 - val_mrcnn_bbox_loss: 0.4225 - val_mrcnn_mask_loss: 0.5298
# Epoch 35/100
# 152/152 [==============================] - 253s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.2576 - rpn_class_loss: 0.0067 - rpn_bbox_loss: 0.0150 - mrcnn_class_loss: 0.0221 - mrcnn_bbox_loss: 0.0287 - mrcnn_mask_loss: 0.1851 - val_loss: 3.0678 - val_rpn_class_loss: 0.3812 - val_rpn_bbox_loss: 0.8748 - val_mrcnn_class_loss: 0.7245 - val_mrcnn_bbox_loss: 0.4342 - val_mrcnn_mask_loss: 0.6531
# Epoch 36/100
# 152/152 [==============================] - 262s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.2636 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.0178 - mrcnn_class_loss: 0.0237 - mrcnn_bbox_loss: 0.0294 - mrcnn_mask_loss: 0.1862 - val_loss: 3.0680 - val_rpn_class_loss: 0.4440 - val_rpn_bbox_loss: 0.8889 - val_mrcnn_class_loss: 0.7999 - val_mrcnn_bbox_loss: 0.4270 - val_mrcnn_mask_loss: 0.5083
# Epoch 37/100
# 152/152 [==============================] - 257s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.2677 - rpn_class_loss: 0.0063 - rpn_bbox_loss: 0.0185 - mrcnn_class_loss: 0.0229 - mrcnn_bbox_loss: 0.0289 - mrcnn_mask_loss: 0.1911 - val_loss: 3.4738 - val_rpn_class_loss: 0.4333 - val_rpn_bbox_loss: 0.9355 - val_mrcnn_class_loss: 1.0573 - val_mrcnn_bbox_loss: 0.4567 - val_mrcnn_mask_loss: 0.5909
# Epoch 38/100
# 152/152 [==============================] - 261s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.2350 - rpn_class_loss: 0.0060 - rpn_bbox_loss: 0.0131 - mrcnn_class_loss: 0.0204 - mrcnn_bbox_loss: 0.0255 - mrcnn_mask_loss: 0.1700 - val_loss: 3.3196 - val_rpn_class_loss: 0.4531 - val_rpn_bbox_loss: 0.9193 - val_mrcnn_class_loss: 0.8660 - val_mrcnn_bbox_loss: 0.4567 - val_mrcnn_mask_loss: 0.6245
# Epoch 39/100
# 152/152 [==============================] - 250s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.2541 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.0200 - mrcnn_class_loss: 0.0208 - mrcnn_bbox_loss: 0.0295 - mrcnn_mask_loss: 0.1774 - val_loss: 3.3164 - val_rpn_class_loss: 0.4131 - val_rpn_bbox_loss: 0.8738 - val_mrcnn_class_loss: 0.8998 - val_mrcnn_bbox_loss: 0.4517 - val_mrcnn_mask_loss: 0.6779
# Epoch 40/100
# 152/152 [==============================] - 263s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.2203 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.0132 - mrcnn_class_loss: 0.0188 - mrcnn_bbox_loss: 0.0235 - mrcnn_mask_loss: 0.1584 - val_loss: 3.4388 - val_rpn_class_loss: 0.4684 - val_rpn_bbox_loss: 0.9350 - val_mrcnn_class_loss: 0.8769 - val_mrcnn_bbox_loss: 0.4460 - val_mrcnn_mask_loss: 0.7125
# Epoch 41/100
# 152/152 [==============================] - 253s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.2191 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.0104 - mrcnn_class_loss: 0.0194 - mrcnn_bbox_loss: 0.0230 - mrcnn_mask_loss: 0.1606 - val_loss: 3.2817 - val_rpn_class_loss: 0.4253 - val_rpn_bbox_loss: 0.8416 - val_mrcnn_class_loss: 0.9772 - val_mrcnn_bbox_loss: 0.4165 - val_mrcnn_mask_loss: 0.6210
# Epoch 42/100
# 152/152 [==============================] - 256s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.2323 - rpn_class_loss: 0.0061 - rpn_bbox_loss: 0.0157 - mrcnn_class_loss: 0.0208 - mrcnn_bbox_loss: 0.0255 - mrcnn_mask_loss: 0.1641 - val_loss: 3.6326 - val_rpn_class_loss: 0.4169 - val_rpn_bbox_loss: 0.8726 - val_mrcnn_class_loss: 1.1972 - val_mrcnn_bbox_loss: 0.4721 - val_mrcnn_mask_loss: 0.6738
# Epoch 43/100
# 152/152 [==============================] - 258s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.2183 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.0148 - mrcnn_class_loss: 0.0186 - mrcnn_bbox_loss: 0.0241 - mrcnn_mask_loss: 0.1549 - val_loss: 3.5191 - val_rpn_class_loss: 0.4409 - val_rpn_bbox_loss: 0.9063 - val_mrcnn_class_loss: 0.9505 - val_mrcnn_bbox_loss: 0.4636 - val_mrcnn_mask_loss: 0.7578
# Epoch 44/100
# 152/152 [==============================] - 260s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1939 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.0110 - mrcnn_class_loss: 0.0161 - mrcnn_bbox_loss: 0.0198 - mrcnn_mask_loss: 0.1424 - val_loss: 3.4576 - val_rpn_class_loss: 0.4936 - val_rpn_bbox_loss: 0.9019 - val_mrcnn_class_loss: 0.9019 - val_mrcnn_bbox_loss: 0.4312 - val_mrcnn_mask_loss: 0.7289
# Epoch 45/100
# 152/152 [==============================] - 276s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.2029 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.0121 - mrcnn_class_loss: 0.0179 - mrcnn_bbox_loss: 0.0208 - mrcnn_mask_loss: 0.1467 - val_loss: 3.7468 - val_rpn_class_loss: 0.4959 - val_rpn_bbox_loss: 0.9359 - val_mrcnn_class_loss: 0.9602 - val_mrcnn_bbox_loss: 0.4698 - val_mrcnn_mask_loss: 0.8850
# Epoch 46/100
# 152/152 [==============================] - 252s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1860 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.0097 - mrcnn_class_loss: 0.0158 - mrcnn_bbox_loss: 0.0188 - mrcnn_mask_loss: 0.1369 - val_loss: 3.5385 - val_rpn_class_loss: 0.4524 - val_rpn_bbox_loss: 0.8900 - val_mrcnn_class_loss: 0.8961 - val_mrcnn_bbox_loss: 0.4381 - val_mrcnn_mask_loss: 0.8618
# Epoch 47/100
# 152/152 [==============================] - 262s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.2119 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.0157 - mrcnn_class_loss: 0.0161 - mrcnn_bbox_loss: 0.0243 - mrcnn_mask_loss: 0.1516 - val_loss: 3.3854 - val_rpn_class_loss: 0.4599 - val_rpn_bbox_loss: 0.9249 - val_mrcnn_class_loss: 0.8678 - val_mrcnn_bbox_loss: 0.4253 - val_mrcnn_mask_loss: 0.7075
# Epoch 48/100
# 152/152 [==============================] - 241s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1921 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.0125 - mrcnn_class_loss: 0.0153 - mrcnn_bbox_loss: 0.0215 - mrcnn_mask_loss: 0.1381 - val_loss: 3.7143 - val_rpn_class_loss: 0.3952 - val_rpn_bbox_loss: 0.8348 - val_mrcnn_class_loss: 1.1532 - val_mrcnn_bbox_loss: 0.4411 - val_mrcnn_mask_loss: 0.8900
# Epoch 49/100
# 152/152 [==============================] - 257s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1882 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.0122 - mrcnn_class_loss: 0.0146 - mrcnn_bbox_loss: 0.0200 - mrcnn_mask_loss: 0.1367 - val_loss: 3.5638 - val_rpn_class_loss: 0.4106 - val_rpn_bbox_loss: 0.8792 - val_mrcnn_class_loss: 0.9020 - val_mrcnn_bbox_loss: 0.4709 - val_mrcnn_mask_loss: 0.9012
# Epoch 50/100
# 152/152 [==============================] - 272s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1810 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.0127 - mrcnn_class_loss: 0.0144 - mrcnn_bbox_loss: 0.0188 - mrcnn_mask_loss: 0.1304 - val_loss: 3.7771 - val_rpn_class_loss: 0.5410 - val_rpn_bbox_loss: 0.9541 - val_mrcnn_class_loss: 1.0340 - val_mrcnn_bbox_loss: 0.4633 - val_mrcnn_mask_loss: 0.7846
# Epoch 51/100
# 152/152 [==============================] - 269s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1840 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.0124 - mrcnn_class_loss: 0.0144 - mrcnn_bbox_loss: 0.0196 - mrcnn_mask_loss: 0.1332 - val_loss: 3.6528 - val_rpn_class_loss: 0.5247 - val_rpn_bbox_loss: 0.8894 - val_mrcnn_class_loss: 1.0858 - val_mrcnn_bbox_loss: 0.4577 - val_mrcnn_mask_loss: 0.6951
# Epoch 52/100
# 152/152 [==============================] - 265s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.2060 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.0173 - mrcnn_class_loss: 0.0170 - mrcnn_bbox_loss: 0.0253 - mrcnn_mask_loss: 0.1422 - val_loss: 3.7850 - val_rpn_class_loss: 0.5438 - val_rpn_bbox_loss: 0.8969 - val_mrcnn_class_loss: 1.2108 - val_mrcnn_bbox_loss: 0.4321 - val_mrcnn_mask_loss: 0.7014
# Epoch 53/100
# 152/152 [==============================] - 279s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1799 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.0122 - mrcnn_class_loss: 0.0140 - mrcnn_bbox_loss: 0.0191 - mrcnn_mask_loss: 0.1302 - val_loss: 3.8655 - val_rpn_class_loss: 0.5339 - val_rpn_bbox_loss: 0.8846 - val_mrcnn_class_loss: 1.1063 - val_mrcnn_bbox_loss: 0.4417 - val_mrcnn_mask_loss: 0.8990
# Epoch 54/100
# 152/152 [==============================] - 256s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1799 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.0140 - mrcnn_class_loss: 0.0141 - mrcnn_bbox_loss: 0.0193 - mrcnn_mask_loss: 0.1278 - val_loss: 3.9280 - val_rpn_class_loss: 0.5437 - val_rpn_bbox_loss: 0.9051 - val_mrcnn_class_loss: 1.2650 - val_mrcnn_bbox_loss: 0.4651 - val_mrcnn_mask_loss: 0.7491
# Epoch 55/100
# 152/152 [==============================] - 271s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1646 - rpn_class_loss: 0.0041 - rpn_bbox_loss: 0.0101 - mrcnn_class_loss: 0.0133 - mrcnn_bbox_loss: 0.0171 - mrcnn_mask_loss: 0.1200 - val_loss: 4.1394 - val_rpn_class_loss: 0.6176 - val_rpn_bbox_loss: 0.9479 - val_mrcnn_class_loss: 1.2712 - val_mrcnn_bbox_loss: 0.4577 - val_mrcnn_mask_loss: 0.8450
# Epoch 56/100
# 152/152 [==============================] - 244s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1718 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.0112 - mrcnn_class_loss: 0.0134 - mrcnn_bbox_loss: 0.0181 - mrcnn_mask_loss: 0.1253 - val_loss: 3.5998 - val_rpn_class_loss: 0.5447 - val_rpn_bbox_loss: 0.8952 - val_mrcnn_class_loss: 1.0910 - val_mrcnn_bbox_loss: 0.4729 - val_mrcnn_mask_loss: 0.5959
# Epoch 57/100
# 152/152 [==============================] - 261s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1763 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.0140 - mrcnn_class_loss: 0.0135 - mrcnn_bbox_loss: 0.0196 - mrcnn_mask_loss: 0.1250 - val_loss: 3.7653 - val_rpn_class_loss: 0.4497 - val_rpn_bbox_loss: 0.8497 - val_mrcnn_class_loss: 1.1397 - val_mrcnn_bbox_loss: 0.4636 - val_mrcnn_mask_loss: 0.8625
# Epoch 58/100
# 152/152 [==============================] - 267s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1643 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.0116 - mrcnn_class_loss: 0.0126 - mrcnn_bbox_loss: 0.0181 - mrcnn_mask_loss: 0.1183 - val_loss: 4.0834 - val_rpn_class_loss: 0.4235 - val_rpn_bbox_loss: 0.8663 - val_mrcnn_class_loss: 1.2282 - val_mrcnn_bbox_loss: 0.4507 - val_mrcnn_mask_loss: 1.1147
# Epoch 59/100
# 152/152 [==============================] - 277s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1680 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.0126 - mrcnn_class_loss: 0.0129 - mrcnn_bbox_loss: 0.0189 - mrcnn_mask_loss: 0.1197 - val_loss: 3.7169 - val_rpn_class_loss: 0.6168 - val_rpn_bbox_loss: 0.9210 - val_mrcnn_class_loss: 0.9347 - val_mrcnn_bbox_loss: 0.4409 - val_mrcnn_mask_loss: 0.8036
# Epoch 60/100
# 152/152 [==============================] - 258s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1548 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.0104 - mrcnn_class_loss: 0.0124 - mrcnn_bbox_loss: 0.0170 - mrcnn_mask_loss: 0.1114 - val_loss: 4.0683 - val_rpn_class_loss: 0.4607 - val_rpn_bbox_loss: 0.8352 - val_mrcnn_class_loss: 1.2298 - val_mrcnn_bbox_loss: 0.4383 - val_mrcnn_mask_loss: 1.1044
# Epoch 61/100
# 152/152 [==============================] - 283s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1610 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.0119 - mrcnn_class_loss: 0.0136 - mrcnn_bbox_loss: 0.0180 - mrcnn_mask_loss: 0.1140 - val_loss: 4.3549 - val_rpn_class_loss: 0.6033 - val_rpn_bbox_loss: 0.8693 - val_mrcnn_class_loss: 1.4481 - val_mrcnn_bbox_loss: 0.4415 - val_mrcnn_mask_loss: 0.9926
# Epoch 62/100
# 152/152 [==============================] - 283s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1446 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.0080 - mrcnn_class_loss: 0.0117 - mrcnn_bbox_loss: 0.0141 - mrcnn_mask_loss: 0.1076 - val_loss: 3.8855 - val_rpn_class_loss: 0.5701 - val_rpn_bbox_loss: 0.8567 - val_mrcnn_class_loss: 1.0767 - val_mrcnn_bbox_loss: 0.4266 - val_mrcnn_mask_loss: 0.9554
# Epoch 63/100
# 152/152 [==============================] - 245s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1412 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.0082 - mrcnn_class_loss: 0.0109 - mrcnn_bbox_loss: 0.0137 - mrcnn_mask_loss: 0.1049 - val_loss: 3.5147 - val_rpn_class_loss: 0.3794 - val_rpn_bbox_loss: 0.7763 - val_mrcnn_class_loss: 1.1772 - val_mrcnn_bbox_loss: 0.4185 - val_mrcnn_mask_loss: 0.7634
# Epoch 64/100
# 152/152 [==============================] - 267s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1454 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0086 - mrcnn_class_loss: 0.0126 - mrcnn_bbox_loss: 0.0144 - mrcnn_mask_loss: 0.1066 - val_loss: 3.7798 - val_rpn_class_loss: 0.5581 - val_rpn_bbox_loss: 0.8627 - val_mrcnn_class_loss: 1.0456 - val_mrcnn_bbox_loss: 0.4418 - val_mrcnn_mask_loss: 0.8716
# Epoch 65/100
# 152/152 [==============================] - 270s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1478 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.0103 - mrcnn_class_loss: 0.0106 - mrcnn_bbox_loss: 0.0157 - mrcnn_mask_loss: 0.1076 - val_loss: 4.1354 - val_rpn_class_loss: 0.5863 - val_rpn_bbox_loss: 0.8632 - val_mrcnn_class_loss: 1.2762 - val_mrcnn_bbox_loss: 0.4471 - val_mrcnn_mask_loss: 0.9626
# Epoch 66/100
# 152/152 [==============================] - 265s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1420 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.0090 - mrcnn_class_loss: 0.0118 - mrcnn_bbox_loss: 0.0150 - mrcnn_mask_loss: 0.1025 - val_loss: 3.9416 - val_rpn_class_loss: 0.5393 - val_rpn_bbox_loss: 0.9022 - val_mrcnn_class_loss: 1.2057 - val_mrcnn_bbox_loss: 0.4374 - val_mrcnn_mask_loss: 0.8570
# Epoch 67/100
# 152/152 [==============================] - 237s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1414 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0087 - mrcnn_class_loss: 0.0114 - mrcnn_bbox_loss: 0.0146 - mrcnn_mask_loss: 0.1036 - val_loss: 3.8703 - val_rpn_class_loss: 0.4479 - val_rpn_bbox_loss: 0.8178 - val_mrcnn_class_loss: 1.0738 - val_mrcnn_bbox_loss: 0.4609 - val_mrcnn_mask_loss: 1.0699
# Epoch 68/100
# 152/152 [==============================] - 279s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1489 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.0102 - mrcnn_class_loss: 0.0118 - mrcnn_bbox_loss: 0.0161 - mrcnn_mask_loss: 0.1072 - val_loss: 4.4965 - val_rpn_class_loss: 0.6765 - val_rpn_bbox_loss: 0.9423 - val_mrcnn_class_loss: 1.3427 - val_mrcnn_bbox_loss: 0.4207 - val_mrcnn_mask_loss: 1.1143
# Epoch 69/100
# 152/152 [==============================] - 266s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1677 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0150 - mrcnn_class_loss: 0.0126 - mrcnn_bbox_loss: 0.0210 - mrcnn_mask_loss: 0.1158 - val_loss: 3.5973 - val_rpn_class_loss: 0.4679 - val_rpn_bbox_loss: 0.8231 - val_mrcnn_class_loss: 0.9509 - val_mrcnn_bbox_loss: 0.4356 - val_mrcnn_mask_loss: 0.9199
# Epoch 70/100
# 152/152 [==============================] - 258s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1482 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.0129 - mrcnn_class_loss: 0.0118 - mrcnn_bbox_loss: 0.0179 - mrcnn_mask_loss: 0.1027 - val_loss: 4.1784 - val_rpn_class_loss: 0.5661 - val_rpn_bbox_loss: 0.9222 - val_mrcnn_class_loss: 1.2385 - val_mrcnn_bbox_loss: 0.4543 - val_mrcnn_mask_loss: 0.9974
# Epoch 71/100
# 152/152 [==============================] - 271s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1478 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0119 - mrcnn_class_loss: 0.0117 - mrcnn_bbox_loss: 0.0180 - mrcnn_mask_loss: 0.1030 - val_loss: 3.7217 - val_rpn_class_loss: 0.6857 - val_rpn_bbox_loss: 0.9111 - val_mrcnn_class_loss: 0.9409 - val_mrcnn_bbox_loss: 0.4094 - val_mrcnn_mask_loss: 0.7746
# Epoch 72/100
# 152/152 [==============================] - 257s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1541 - rpn_class_loss: 0.0033 - rpn_bbox_loss: 0.0138 - mrcnn_class_loss: 0.0124 - mrcnn_bbox_loss: 0.0178 - mrcnn_mask_loss: 0.1069 - val_loss: 3.9108 - val_rpn_class_loss: 0.5998 - val_rpn_bbox_loss: 0.9293 - val_mrcnn_class_loss: 1.0616 - val_mrcnn_bbox_loss: 0.4442 - val_mrcnn_mask_loss: 0.8760
# Epoch 73/100
# 152/152 [==============================] - 267s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1443 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0111 - mrcnn_class_loss: 0.0119 - mrcnn_bbox_loss: 0.0169 - mrcnn_mask_loss: 0.1012 - val_loss: 3.7035 - val_rpn_class_loss: 0.6000 - val_rpn_bbox_loss: 0.8973 - val_mrcnn_class_loss: 1.0142 - val_mrcnn_bbox_loss: 0.4260 - val_mrcnn_mask_loss: 0.7660
# Epoch 74/100
# 152/152 [==============================] - 254s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1378 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.0100 - mrcnn_class_loss: 0.0101 - mrcnn_bbox_loss: 0.0158 - mrcnn_mask_loss: 0.0983 - val_loss: 4.2342 - val_rpn_class_loss: 0.6501 - val_rpn_bbox_loss: 0.8783 - val_mrcnn_class_loss: 1.2731 - val_mrcnn_bbox_loss: 0.4406 - val_mrcnn_mask_loss: 0.9921
# Epoch 75/100
# 152/152 [==============================] - 272s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1343 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.0093 - mrcnn_class_loss: 0.0104 - mrcnn_bbox_loss: 0.0153 - mrcnn_mask_loss: 0.0964 - val_loss: 4.0149 - val_rpn_class_loss: 0.6279 - val_rpn_bbox_loss: 0.8723 - val_mrcnn_class_loss: 1.1067 - val_mrcnn_bbox_loss: 0.4312 - val_mrcnn_mask_loss: 0.9768
# Epoch 76/100
# 152/152 [==============================] - 275s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1309 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.0087 - mrcnn_class_loss: 0.0106 - mrcnn_bbox_loss: 0.0139 - mrcnn_mask_loss: 0.0943 - val_loss: 3.8574 - val_rpn_class_loss: 0.6071 - val_rpn_bbox_loss: 0.9868 - val_mrcnn_class_loss: 0.9260 - val_mrcnn_bbox_loss: 0.4049 - val_mrcnn_mask_loss: 0.9325
# Epoch 77/100
# 152/152 [==============================] - 280s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1505 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0146 - mrcnn_class_loss: 0.0122 - mrcnn_bbox_loss: 0.0172 - mrcnn_mask_loss: 0.1037 - val_loss: 4.1533 - val_rpn_class_loss: 0.7439 - val_rpn_bbox_loss: 0.8909 - val_mrcnn_class_loss: 1.1758 - val_mrcnn_bbox_loss: 0.4178 - val_mrcnn_mask_loss: 0.9247
# Epoch 78/100
# 152/152 [==============================] - 289s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1623 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0131 - mrcnn_class_loss: 0.0122 - mrcnn_bbox_loss: 0.0186 - mrcnn_mask_loss: 0.1151 - val_loss: 4.3980 - val_rpn_class_loss: 0.6733 - val_rpn_bbox_loss: 0.8739 - val_mrcnn_class_loss: 1.3601 - val_mrcnn_bbox_loss: 0.4623 - val_mrcnn_mask_loss: 1.0285
# Epoch 79/100
# 152/152 [==============================] - 248s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1307 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.0095 - mrcnn_class_loss: 0.0093 - mrcnn_bbox_loss: 0.0156 - mrcnn_mask_loss: 0.0938 - val_loss: 4.1708 - val_rpn_class_loss: 0.6042 - val_rpn_bbox_loss: 0.8916 - val_mrcnn_class_loss: 1.2956 - val_mrcnn_bbox_loss: 0.4348 - val_mrcnn_mask_loss: 0.9446
# Epoch 80/100
# 152/152 [==============================] - 254s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1560 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.0150 - mrcnn_class_loss: 0.0113 - mrcnn_bbox_loss: 0.0194 - mrcnn_mask_loss: 0.1073 - val_loss: 4.2332 - val_rpn_class_loss: 0.4801 - val_rpn_bbox_loss: 0.8334 - val_mrcnn_class_loss: 1.4014 - val_mrcnn_bbox_loss: 0.4684 - val_mrcnn_mask_loss: 1.0499
# Epoch 81/100
# 152/152 [==============================] - 262s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1338 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0104 - mrcnn_class_loss: 0.0107 - mrcnn_bbox_loss: 0.0152 - mrcnn_mask_loss: 0.0948 - val_loss: 4.0077 - val_rpn_class_loss: 0.4791 - val_rpn_bbox_loss: 0.8235 - val_mrcnn_class_loss: 1.2480 - val_mrcnn_bbox_loss: 0.4549 - val_mrcnn_mask_loss: 1.0022
# Epoch 82/100
# 152/152 [==============================] - 246s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1410 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0131 - mrcnn_class_loss: 0.0103 - mrcnn_bbox_loss: 0.0173 - mrcnn_mask_loss: 0.0974 - val_loss: 3.9270 - val_rpn_class_loss: 0.5980 - val_rpn_bbox_loss: 0.9070 - val_mrcnn_class_loss: 0.9979 - val_mrcnn_bbox_loss: 0.4087 - val_mrcnn_mask_loss: 1.0155
# Epoch 83/100
# 152/152 [==============================] - 257s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1308 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0094 - mrcnn_class_loss: 0.0099 - mrcnn_bbox_loss: 0.0153 - mrcnn_mask_loss: 0.0935 - val_loss: 4.3710 - val_rpn_class_loss: 0.5969 - val_rpn_bbox_loss: 0.8982 - val_mrcnn_class_loss: 1.3054 - val_mrcnn_bbox_loss: 0.4747 - val_mrcnn_mask_loss: 1.0958
# Epoch 84/100
# 152/152 [==============================] - 271s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1591 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.0177 - mrcnn_class_loss: 0.0109 - mrcnn_bbox_loss: 0.0230 - mrcnn_mask_loss: 0.1040 - val_loss: 3.8143 - val_rpn_class_loss: 0.5405 - val_rpn_bbox_loss: 0.8475 - val_mrcnn_class_loss: 1.0209 - val_mrcnn_bbox_loss: 0.4276 - val_mrcnn_mask_loss: 0.9779
# Epoch 85/100
# 152/152 [==============================] - 263s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1280 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0115 - mrcnn_class_loss: 0.0098 - mrcnn_bbox_loss: 0.0137 - mrcnn_mask_loss: 0.0903 - val_loss: 4.3892 - val_rpn_class_loss: 0.5914 - val_rpn_bbox_loss: 0.8592 - val_mrcnn_class_loss: 1.3360 - val_mrcnn_bbox_loss: 0.4706 - val_mrcnn_mask_loss: 1.1321
# Epoch 86/100
# 152/152 [==============================] - 254s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1435 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0134 - mrcnn_class_loss: 0.0115 - mrcnn_bbox_loss: 0.0173 - mrcnn_mask_loss: 0.0985 - val_loss: 3.9944 - val_rpn_class_loss: 0.5311 - val_rpn_bbox_loss: 0.8550 - val_mrcnn_class_loss: 1.1918 - val_mrcnn_bbox_loss: 0.4519 - val_mrcnn_mask_loss: 0.9645
# Epoch 87/100
# 152/152 [==============================] - 265s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1503 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.0134 - mrcnn_class_loss: 0.0101 - mrcnn_bbox_loss: 0.0188 - mrcnn_mask_loss: 0.1051 - val_loss: 3.9815 - val_rpn_class_loss: 0.5668 - val_rpn_bbox_loss: 0.8539 - val_mrcnn_class_loss: 1.2138 - val_mrcnn_bbox_loss: 0.4098 - val_mrcnn_mask_loss: 0.9371
# Epoch 88/100
# 152/152 [==============================] - 259s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1335 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.0108 - mrcnn_class_loss: 0.0097 - mrcnn_bbox_loss: 0.0168 - mrcnn_mask_loss: 0.0931 - val_loss: 4.0963 - val_rpn_class_loss: 0.5657 - val_rpn_bbox_loss: 0.8718 - val_mrcnn_class_loss: 1.0794 - val_mrcnn_bbox_loss: 0.4630 - val_mrcnn_mask_loss: 1.1164
# Epoch 89/100
# 152/152 [==============================] - 251s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1365 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.0128 - mrcnn_class_loss: 0.0089 - mrcnn_bbox_loss: 0.0184 - mrcnn_mask_loss: 0.0938 - val_loss: 4.0569 - val_rpn_class_loss: 0.5755 - val_rpn_bbox_loss: 0.9144 - val_mrcnn_class_loss: 1.0903 - val_mrcnn_bbox_loss: 0.4552 - val_mrcnn_mask_loss: 1.0214
# Epoch 90/100
# 152/152 [==============================] - 263s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1418 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0137 - mrcnn_class_loss: 0.0098 - mrcnn_bbox_loss: 0.0189 - mrcnn_mask_loss: 0.0966 - val_loss: 3.9458 - val_rpn_class_loss: 0.5356 - val_rpn_bbox_loss: 0.7958 - val_mrcnn_class_loss: 1.2160 - val_mrcnn_bbox_loss: 0.4517 - val_mrcnn_mask_loss: 0.9468
# Epoch 91/100
# 152/152 [==============================] - 255s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1351 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.0118 - mrcnn_class_loss: 0.0095 - mrcnn_bbox_loss: 0.0186 - mrcnn_mask_loss: 0.0923 - val_loss: 3.8516 - val_rpn_class_loss: 0.4923 - val_rpn_bbox_loss: 0.8229 - val_mrcnn_class_loss: 1.1031 - val_mrcnn_bbox_loss: 0.4552 - val_mrcnn_mask_loss: 0.9781
# Epoch 92/100
# 152/152 [==============================] - 273s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1304 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.0112 - mrcnn_class_loss: 0.0109 - mrcnn_bbox_loss: 0.0168 - mrcnn_mask_loss: 0.0886 - val_loss: 4.1788 - val_rpn_class_loss: 0.6988 - val_rpn_bbox_loss: 0.8385 - val_mrcnn_class_loss: 1.1078 - val_mrcnn_bbox_loss: 0.4463 - val_mrcnn_mask_loss: 1.0874
# Epoch 93/100
# 152/152 [==============================] - 259s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1437 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0147 - mrcnn_class_loss: 0.0111 - mrcnn_bbox_loss: 0.0199 - mrcnn_mask_loss: 0.0953 - val_loss: 3.7522 - val_rpn_class_loss: 0.5392 - val_rpn_bbox_loss: 0.8635 - val_mrcnn_class_loss: 1.0322 - val_mrcnn_bbox_loss: 0.4516 - val_mrcnn_mask_loss: 0.8656
# Epoch 94/100
# 152/152 [==============================] - 250s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1707 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.0202 - mrcnn_class_loss: 0.0119 - mrcnn_bbox_loss: 0.0254 - mrcnn_mask_loss: 0.1095 - val_loss: 3.7656 - val_rpn_class_loss: 0.5551 - val_rpn_bbox_loss: 0.8294 - val_mrcnn_class_loss: 1.0578 - val_mrcnn_bbox_loss: 0.4202 - val_mrcnn_mask_loss: 0.9031
# Epoch 95/100
# 152/152 [==============================] - 270s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1492 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0143 - mrcnn_class_loss: 0.0101 - mrcnn_bbox_loss: 0.0204 - mrcnn_mask_loss: 0.1013 - val_loss: 3.8797 - val_rpn_class_loss: 0.6536 - val_rpn_bbox_loss: 0.8860 - val_mrcnn_class_loss: 0.8853 - val_mrcnn_bbox_loss: 0.4086 - val_mrcnn_mask_loss: 1.0462
# Epoch 96/100
# 152/152 [==============================] - 269s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1451 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.0150 - mrcnn_class_loss: 0.0099 - mrcnn_bbox_loss: 0.0200 - mrcnn_mask_loss: 0.0972 - val_loss: 3.9137 - val_rpn_class_loss: 0.5276 - val_rpn_bbox_loss: 0.8802 - val_mrcnn_class_loss: 1.1338 - val_mrcnn_bbox_loss: 0.4261 - val_mrcnn_mask_loss: 0.9460
# Epoch 97/100
# 152/152 [==============================] - 258s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1411 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0141 - mrcnn_class_loss: 0.0110 - mrcnn_bbox_loss: 0.0194 - mrcnn_mask_loss: 0.0941 - val_loss: 4.1699 - val_rpn_class_loss: 0.6181 - val_rpn_bbox_loss: 0.9236 - val_mrcnn_class_loss: 1.2869 - val_mrcnn_bbox_loss: 0.4057 - val_mrcnn_mask_loss: 0.9357
# Epoch 98/100
# 152/152 [==============================] - 267s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1188 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.0087 - mrcnn_class_loss: 0.0095 - mrcnn_bbox_loss: 0.0133 - mrcnn_mask_loss: 0.0844 - val_loss: 4.5072 - val_rpn_class_loss: 0.6972 - val_rpn_bbox_loss: 0.9718 - val_mrcnn_class_loss: 1.3473 - val_mrcnn_bbox_loss: 0.4344 - val_mrcnn_mask_loss: 1.0566
# Epoch 99/100
# 152/152 [==============================] - 246s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1180 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0080 - mrcnn_class_loss: 0.0089 - mrcnn_bbox_loss: 0.0130 - mrcnn_mask_loss: 0.0853 - val_loss: 3.9924 - val_rpn_class_loss: 0.5477 - val_rpn_bbox_loss: 0.8756 - val_mrcnn_class_loss: 1.1256 - val_mrcnn_bbox_loss: 0.4298 - val_mrcnn_mask_loss: 1.0137
# Epoch 100/100
# 152/152 [==============================] - 261s 2s/step - batch: 75.5000 - size: 2.0000 - loss: 0.1586 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.0167 - mrcnn_class_loss: 0.0123 - mrcnn_bbox_loss: 0.0244 - mrcnn_mask_loss: 0.1026 - val_loss: 3.9153 - val_rpn_class_loss: 0.6907 - val_rpn_bbox_loss: 0.9085 - val_mrcnn_class_loss: 1.1466 - val_mrcnn_bbox_loss: 0.4061 - val_mrcnn_mask_loss: 0.7634
