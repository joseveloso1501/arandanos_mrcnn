# %% [markdown]
# # Test 6 (paper) - Experimento 4 (PT)
#
# Entrenamiento de Mask R-CNN con dataset modificado para emular "Test 6"
#
# ### Hiperparametros
# * **epoch = 100**
#     * steps x epoch = 146 (lotes de imagenes)
#     * batch = 2
# * optimizador = SGD
# * Funcion de perdida = SMOOTHL1LOSS
# * Metrica de evaluacion = mAP (IoU >= 0.5)
# * Mini-mask shape: 56x56
# * RPN anchor scales: (32, 64, 128, 256, 512)
# * Tasa de aprendizaje: 0.001
# * imagenes = 292
#     * entrenamiento 81% = 237
#     * validacion 19% = 55
# * etiquetas = 9140
# * **resolucion = 1024 x 800**
# * etiquetas = bounding box formato VOC XML
# * numero de clases = 1 (arandano)
# * **data augmentation = true**

# %% [markdown]
# ## Comprobar directorio principal

# %%
# !pwd && ls -l
# Out:
# /tf/PT_JoseVeloso/Mask_RCNN-master_matterport/model-training
# total 1576
# drwxr-xr-x 4 root root   4096 Aug  7 06:10 build
# drwxr-xr-x 2 root root   4096 Aug  7 06:10 dist
# drwxr-xr-x 2 root root   4096 Aug  8 03:15 mask_rcnn.egg-info
# -rw-r--r-- 1 root root  67789 Sep 16 23:55 master-test_11.ipynb
# -rw-r--r-- 1 root root  88232 Sep 17 07:27 master-test_11_fase_2-Copy1.ipynb
# -rw-r--r-- 1 root root  67792 Sep 17 08:36 master-test_11_fase_2.ipynb
# -rw-r--r-- 1 root root  30144 Sep 16 23:44 master-test_12.ipynb
# -rw-r--r-- 1 root root  30144 Sep 16 22:02 master-test_12_fase_2.ipynb
# -rw-r--r-- 1 root root 350337 Sep 15 00:38 master-test_5-fase_2.ipynb
# -rw-r--r-- 1 root root 350144 Sep 17 08:42 master-test_5_fase_2.ipynb
# -rw-r--r-- 1 root root 111017 Sep 18 16:23 master-test_6.ipynb
# -rw-r--r-- 1 root root 270148 Sep 17 16:09 master-test_6_fase_2.ipynb
# drwxr-xr-x 4 root root   4096 Sep 18 19:33 mrcnn
# drwxr-xr-x 3 root root   4096 Sep 15 02:27 old
# -rw-r--r-- 1 root root 163666 Sep 18 15:38 test_5_corregido.ipynb
# -rw-r--r-- 1 root root  41037 Sep 18 19:32 test_6_corregido.ipynb

# %% [markdown]
# # Importar bibliotecas

# %%
# bibliotecas basicas
import os
from os import listdir
import sys
import json
import datetime

#sys.path.append("/tf/PT_JoseVeloso/Mask_RCNN-master/")

# bibliotecas avanzadas 
from xml.etree import ElementTree
import skimage.draw
import cv2
import imgaug

# bibliotecas mask rcnn 
from mrcnn.utils import Dataset
from mrcnn.config import Config
from mrcnn.model import MaskRCNN
from mrcnn.visualize import display_instances
from mrcnn.utils import extract_bboxes
from mrcnn.utils import compute_ap
from mrcnn.model import load_image_gt
from mrcnn.model import mold_image
from mrcnn import visualize

# biblioteca matplotlib 
import matplotlib.pyplot as plt

# bibliotecas numpy 
import numpy as np
from numpy import zeros
from numpy import asarray
from numpy import expand_dims
from numpy import mean

# bibliotecas keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img   #keras.preprocessing.image tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

# ignorar alertas de elementos que seran descontinuados
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

# %matplotlib inline
#plt.show()

import imgaug.augmenters as iaa

# %% [markdown]
# # Entrenamiento con una sola clase y etiquetas de Bounding Box

# %% [markdown]
# En este entremamiento se utiliza un conjunto de datos simple con imágenes etiquetadas con cuadros delimitadores y una clase llamada 'Daño'. En la siguiente sección se encuentra el código para el entrenamiento del modelo. Se incluyen comentarios para describir mejor el flujo del programa.

# %%
class DatasetArandanos(Dataset):
    
    # la funcion load_dataset es usada para cargar el dataset de entrenamiento y test
    def load_dataset(self, dataset_dir, is_train=True):
        
        # se agrega una clase que se necesita para clasificar, en este caso arandano
        self.add_class("dataset", 1, "arandano")
        
        # se concatena dataset_dir con /images y /annots
        images_dir = dataset_dir + '/images/'
        annotations_dir = dataset_dir + '/annots/'
        
        # is_train sera Verdadero si se esta entrenando el modelo y Falso si se esta testeando el modelo
        for filename in listdir(images_dir):
            
            # extraer image id
            image_id = filename[:-4] # se usa para omitir los últimos 4 caracteres: '.jpg' (en class_id.jpg)
            
            # si is_train es Verdadero se omiten todas las imágenes con id mayor que e iguales a 11074
            # aproximadamente el 80% del conjunto de datos es para entrenamiento
            
            if is_train and int(image_id) >= 41590 :
                #vprint("image_id: ", image_id)
                continue
            
            # si is_train no es Verdadero se omiten todas las imágenes con id menores a 11074
            if not is_train and int(image_id) < 41590:
                continue
            
            # se declara la ruta de la imagen y la ruta de las etiquetas 
            img_path = images_dir + filename
            ann_path = annotations_dir + image_id + '.xml'
            
            # usando la función add_image se pasan image_id, image_path y ann_path para que la 
            # imagen actual se agregue al conjunto de datos para entrenamiento o prueba
            self.add_image('dataset', image_id=image_id, path=img_path, annotation=ann_path)

    # funcino usada para extraer bouding boxes desde archivos etiquetados 
    def extract_boxes(self, filename):

        # se puede ver en las imágenes que estan etiquetadas, como se extraen los valores de ancho, alto y bndbox
        
        # <annotation>
        # <size>

        #       <width>640</width>

        #       <height>360</height>

        #       <depth>3</depth>

        # </size>


        # <object>

        #          <name>damage</name>

        #          <pose>Unspecified</pose>

        #          <truncated>0</truncated>

        #          <difficult>0</difficult>


        #          <bndbox>

        #                 <xmin>315</xmin>

        #                 <ymin>160</ymin>

        #                 <xmax>381</xmax>

        #                 <ymax>199</ymax>

        #          </bndbox>

        # </object>
        # </annotation>
        
        # para analizar los archivos .xml
        tree = ElementTree.parse(filename)
        
        # para obtener la raíz del archivo xml
        root = tree.getroot()
        
        # se agregan todas las coordenadas x, y en boxes para todas las instancias de un objeto
        boxes = list()
        
        # se encuentran todos los atributos con el nombre bndbox que existan para cada ground truth en la imagen
        for box in root.findall('.//bndbox'):
            xmin = int(box.find('xmin').text)
            ymin = int(box.find('ymin').text)
            xmax = int(box.find('xmax').text)
            ymax = int(box.find('ymax').text)
            coors = [xmin, ymin, xmax, ymax]
            boxes.append(coors)
        
        # extraer ancho y alto de la imagen
        width = int(root.find('.//size/width').text)
        height = int(root.find('.//size/height').text)
        
        # retorna boxes-> list, width-> int y height-> int 
        return boxes, width, height
    
    # this function calls on the extract_boxes method and is used to load a mask for each instance in an image
    # returns a boolean mask with following dimensions width * height * instances

    # esta función llama al método extract_boxes y se usa para cargar una máscara para cada instancia en una imagen 
    # devuelve una máscara booleana con las siguientes dimensiones ancho * alto * instancias
    def load_mask(self, image_id):
        
        # info apunta al image_id actual 
        info = self.image_info[image_id]
        
        # se obtiene la ruta de anotación de image_id que es dataset_dir/annots/image_id.xml 
        path = info['annotation']
        
        # se llama al método extract_boxes (arriba) para obtener bndbox del archivo .xml
        boxes, w, h = self.extract_boxes(path)
        
        # se crea una cantidad de len(boxes) de mascaras de alto 'h' y ancho 'w'
        masks = zeros([h, w, len(boxes)], dtype='uint8')
        
        # se agrega (append) el class_id 1 para arandano en nuestro caso a la variable
        class_ids = list()
        
        # se recorren todos los boxes y generamos máscaras (máscara de bndbox) y class id para cada instancia
        # las máscaras tendrán forma rectangular ya que hemos usado bndboxes para etiquetas
        # por ejemplo: si 2.jpg tiene tres objetos, tendremos las siguientes máscaras y class_ids.

        # 000000000 000000000 000001110 
        # 000011100 011100000 000001110
        # 000011100 011100000 000001110
        # 000000000 011100000 000000000
        #    1         1          1    <- class_ids
        for i in range(len(boxes)):
            box = boxes[i]
            row_s, row_e = box[1], box[3]
            col_s, col_e = box[0], box[2]
            masks[row_s:row_e, col_s:col_e, i] = 1
            class_ids.append(self.class_names.index('arandano'))
        
        # retorna mascaras y class_ids como arreglo
        return masks, asarray(class_ids, dtype='int32')
    
    # esta funciones toma el image_id y retorna la ruta de la imagen 
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

# %%
# clase de configuracion arandano, aqui se pueden cambiar valores de hyper parameters 
class ConfigArandanos(Config):

    # nombre de la configuracion 
    NAME = "arandano_cfg_test_6_2_"    
    
    # clase arandano + clase background 
    NUM_CLASSES = 1 + 1
    
    # pasos por epoch y confianza minima    # STEPS_PER_EPOCH = cantidad de lotes/batchs
    #STEPS_PER_EPOCH = 73   # por epoch se entrenaran 73 lotes de 4 imagenes, dataset = 292
    STEPS_PER_EPOCH = 146
    
    # tasa de aprendizaje y momentum
    LEARNING_RATE=0.001
    LEARNING_MOMENTUM = 0.8
    
    # penalización de regularización
    WEIGHT_DECAY = 0.0001
    
    # el tamaño de la imagen está controlado por este parámetro
    IMAGE_MIN_DIM = 512
    
    # pasos de validación
    VALIDATION_STEPS = 50
    
    # número de regiones de interés generadas por imagen
    Train_ROIs_Per_Image = 200
    
    # escala de anclas RPN y proporciones (ratios) para encontrar la ROI
    RPN_ANCHOR_SCALES = (32, 64, 128, 256, 512)    # Longitud del lado del ancla cuadrada, en píxeles 
    RPN_ANCHOR_RATIOS = [0.5, 1, 1.5]   # Proporciones de anclas por cada celda (ancho/alto). Un valor de 1 representa un ancla cuadrada y 0,5 es un ancla ancha 
    
    #DEVICE = "/cpu:0"  # /cpu:0 or /gpu:0    
    DEVICE = "/gpu:0"  # /cpu:0 or /gpu:0

    IMAGES_PER_GPU = 2
    
ConfigArandanos().display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# DEVICE                         /gpu:0
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.8
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           arandano_cfg_6_2_
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 1.5]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                146
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# Train_ROIs_Per_Image           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ### Entrenamiento

# %%
cd /tf/PT_JoseVeloso/Mask_RCNN-master_matterport/
# Out:
# /tf/PT_JoseVeloso/Mask_RCNN-master_matterport

# %%
#pesos = 'mask_rcnn_coco.h5'
#pesos = 'mask_rcnn_damage_cfg_0049.h5'
#pesos = 'arandano_cfg_test_5_20220907T0914/mask_rcnn_arandano_cfg_0300.h5'
#pesos = 'arandano_cfg20220907T0914/mask_rcnn_arandano_cfg_0300.h5'
pesos = 'arandano_cfg_test_5_2_20220917T0844/mask_rcnn_arandano_cfg_test_5_2__0300.h5'

conjunto_datos = 'customImages/test_6'

# %%
# cargar dataset de entrenamiento
train_set = DatasetArandanos()
train_set.load_dataset(conjunto_datos, is_train=True)
train_set.prepare()

# cargar dataset de test 
test_set = DatasetArandanos()
test_set.load_dataset(conjunto_datos, is_train=False)
test_set.prepare()

# preparar la configuración llamando a la clase de configuración definida por el usuario
config = ConfigArandanos()

# definir el modelo
with tf.device(config.DEVICE):
    model = MaskRCNN(mode='training', model_dir='./', config=config)

# cargar pesos del modelo
weights_path = pesos

# cargar los pesos del modelo
model.load_weights(weights_path, 
                   by_name=True, 
                   exclude=["mrcnn_class_logits", "mrcnn_bbox_fc",  "mrcnn_bbox", "mrcnn_mask"])

#augmentation = iaa.Sequential(iaa.Fliplr(0.5), iaa.Flipud(0.5))
#augmentation = iaa.Sequential([iaa.Fliplr(0.5), iaa.Flipud(0.5)])
#augmentation = iaa.Sometimes(5/6, iaa.Fliplr(0.5), iaa.Flipud(0.5))
augmentation = iaa.Sometimes(0.5, iaa.Fliplr(0.5), iaa.Flipud(0.5))

# iniciar entrenamiento del modelo
model.train(train_set, test_set, learning_rate=config.LEARNING_RATE, epochs=100, layers='all', augmentation=augmentation)
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: ./arandano_cfg_6_2_20220918T1934/mask_rcnn_arandano_cfg_6_2__{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res4g_branch2a         (Conv2D)
# bn4g_branch2a          (BatchNorm)
# res4g_branch2b         (Conv2D)
# bn4g_branch2b          (BatchNorm)
# res4g_branch2c         (Conv2D)
# bn4g_branch2c          (BatchNorm)
# res4h_branch2a         (Conv2D)
# bn4h_branch2a          (BatchNorm)
# res4h_branch2b         (Conv2D)
# bn4h_branch2b          (BatchNorm)
# res4h_branch2c         (Conv2D)
# bn4h_branch2c          (BatchNorm)
# res4i_branch2a         (Conv2D)
# bn4i_branch2a          (BatchNorm)
# res4i_branch2b         (Conv2D)
# bn4i_branch2b          (BatchNorm)
# res4i_branch2c         (Conv2D)
# bn4i_branch2c          (BatchNorm)
# res4j_branch2a         (Conv2D)
# bn4j_branch2a          (BatchNorm)
# res4j_branch2b         (Conv2D)
# bn4j_branch2b          (BatchNorm)
# res4j_branch2c         (Conv2D)
# bn4j_branch2c          (BatchNorm)
# res4k_branch2a         (Conv2D)
# bn4k_branch2a          (BatchNorm)
# res4k_branch2b         (Conv2D)
# bn4k_branch2b          (BatchNorm)
# res4k_branch2c         (Conv2D)
# bn4k_branch2c          (BatchNorm)
# res4l_branch2a         (Conv2D)
# bn4l_branch2a          (BatchNorm)
# res4l_branch2b         (Conv2D)
# bn4l_branch2b          (BatchNorm)
# res4l_branch2c         (Conv2D)
# bn4l_branch2c          (BatchNorm)
# res4m_branch2a         (Conv2D)
# bn4m_branch2a          (BatchNorm)
# res4m_branch2b         (Conv2D)
# bn4m_branch2b          (BatchNorm)
# res4m_branch2c         (Conv2D)
# bn4m_branch2c          (BatchNorm)
# res4n_branch2a         (Conv2D)
# bn4n_branch2a          (BatchNorm)
# res4n_branch2b         (Conv2D)
# bn4n_branch2b          (BatchNorm)
# res4n_branch2c         (Conv2D)
# bn4n_branch2c          (BatchNorm)
# res4o_branch2a         (Conv2D)
# bn4o_branch2a          (BatchNorm)
# res4o_branch2b         (Conv2D)
# bn4o_branch2b          (BatchNorm)
# res4o_branch2c         (Conv2D)
# bn4o_branch2c          (BatchNorm)
# res4p_branch2a         (Conv2D)
# bn4p_branch2a          (BatchNorm)
# res4p_branch2b         (Conv2D)
# bn4p_branch2b          (BatchNorm)
# res4p_branch2c         (Conv2D)
# bn4p_branch2c          (BatchNorm)
# res4q_branch2a         (Conv2D)
# bn4q_branch2a          (BatchNorm)
# res4q_branch2b         (Conv2D)
# bn4q_branch2b          (BatchNorm)
# res4q_branch2c         (Conv2D)
# bn4q_branch2c          (BatchNorm)
# res4r_branch2a         (Conv2D)
# bn4r_branch2a          (BatchNorm)
# res4r_branch2b         (Conv2D)
# bn4r_branch2b          (BatchNorm)
# res4r_branch2c         (Conv2D)
# bn4r_branch2c          (BatchNorm)
# res4s_branch2a         (Conv2D)
# bn4s_branch2a          (BatchNorm)
# res4s_branch2b         (Conv2D)
# bn4s_branch2b          (BatchNorm)
# res4s_branch2c         (Conv2D)
# bn4s_branch2c          (BatchNorm)
# res4t_branch2a         (Conv2D)
# bn4t_branch2a          (BatchNorm)
# res4t_branch2b         (Conv2D)
# bn4t_branch2b          (BatchNorm)
# res4t_branch2c         (Conv2D)
# bn4t_branch2c          (BatchNorm)
# res4u_branch2a         (Conv2D)
# bn4u_branch2a          (BatchNorm)
# res4u_branch2b         (Conv2D)
# bn4u_branch2b          (BatchNorm)
# res4u_branch2c         (Conv2D)
# bn4u_branch2c          (BatchNorm)
# res4v_branch2a         (Conv2D)
# bn4v_branch2a          (BatchNorm)
# res4v_branch2b         (Conv2D)
# bn4v_branch2b          (BatchNorm)
# res4v_branch2c         (Conv2D)
# bn4v_branch2c          (BatchNorm)
# res4w_branch2a         (Conv2D)
# bn4w_branch2a          (BatchNorm)
# res4w_branch2b         (Conv2D)
# bn4w_branch2b          (BatchNorm)
# res4w_branch2c         (Conv2D)
# bn4w_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# rpn_model              (Functional)
# anchors                (AnchorsLayer)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/100
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/sub:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/GatherV2_2:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/Shape:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/sub_1:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/GatherV2_5:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/Shape_1:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/sub_2:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/GatherV2_8:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/sub_3:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/GatherV2_11:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# 146/146 [==============================] - 418s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 4.0455 - rpn_class_loss: 0.8756 - rpn_bbox_loss: 1.4512 - mrcnn_class_loss: 0.3759 - mrcnn_bbox_loss: 0.8254 - mrcnn_mask_loss: 0.5174 - val_loss: 2.6969 - val_rpn_class_loss: 0.5630 - val_rpn_bbox_loss: 0.7633 - val_mrcnn_class_loss: 0.4148 - val_mrcnn_bbox_loss: 0.4702 - val_mrcnn_mask_loss: 0.4856
# Epoch 2/100
# 146/146 [==============================] - 353s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 2.1509 - rpn_class_loss: 0.3550 - rpn_bbox_loss: 0.5227 - mrcnn_class_loss: 0.3560 - mrcnn_bbox_loss: 0.4493 - mrcnn_mask_loss: 0.4680 - val_loss: 2.8649 - val_rpn_class_loss: 0.5699 - val_rpn_bbox_loss: 0.7411 - val_mrcnn_class_loss: 0.4982 - val_mrcnn_bbox_loss: 0.5398 - val_mrcnn_mask_loss: 0.5160
# Epoch 3/100
# 146/146 [==============================] - 355s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.9259 - rpn_class_loss: 0.2751 - rpn_bbox_loss: 0.4302 - mrcnn_class_loss: 0.3973 - mrcnn_bbox_loss: 0.3892 - mrcnn_mask_loss: 0.4341 - val_loss: 2.4173 - val_rpn_class_loss: 0.4868 - val_rpn_bbox_loss: 0.5983 - val_mrcnn_class_loss: 0.4895 - val_mrcnn_bbox_loss: 0.4030 - val_mrcnn_mask_loss: 0.4396
# Epoch 4/100
# 146/146 [==============================] - 374s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.8464 - rpn_class_loss: 0.2504 - rpn_bbox_loss: 0.4006 - mrcnn_class_loss: 0.4141 - mrcnn_bbox_loss: 0.3603 - mrcnn_mask_loss: 0.4209 - val_loss: 2.4427 - val_rpn_class_loss: 0.4625 - val_rpn_bbox_loss: 0.5865 - val_mrcnn_class_loss: 0.5438 - val_mrcnn_bbox_loss: 0.3999 - val_mrcnn_mask_loss: 0.4500
# Epoch 5/100
# 146/146 [==============================] - 414s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.7691 - rpn_class_loss: 0.2294 - rpn_bbox_loss: 0.3848 - mrcnn_class_loss: 0.4059 - mrcnn_bbox_loss: 0.3362 - mrcnn_mask_loss: 0.4128 - val_loss: 2.2040 - val_rpn_class_loss: 0.3575 - val_rpn_bbox_loss: 0.5637 - val_mrcnn_class_loss: 0.5051 - val_mrcnn_bbox_loss: 0.3556 - val_mrcnn_mask_loss: 0.4220
# Epoch 6/100
# 146/146 [==============================] - 372s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.6953 - rpn_class_loss: 0.2206 - rpn_bbox_loss: 0.3673 - mrcnn_class_loss: 0.3875 - mrcnn_bbox_loss: 0.3191 - mrcnn_mask_loss: 0.4008 - val_loss: 2.3416 - val_rpn_class_loss: 0.4203 - val_rpn_bbox_loss: 0.5835 - val_mrcnn_class_loss: 0.5277 - val_mrcnn_bbox_loss: 0.3772 - val_mrcnn_mask_loss: 0.4329
# Epoch 7/100
# 146/146 [==============================] - 354s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.6170 - rpn_class_loss: 0.2016 - rpn_bbox_loss: 0.3450 - mrcnn_class_loss: 0.3771 - mrcnn_bbox_loss: 0.3043 - mrcnn_mask_loss: 0.3890 - val_loss: 2.2073 - val_rpn_class_loss: 0.4302 - val_rpn_bbox_loss: 0.4958 - val_mrcnn_class_loss: 0.5132 - val_mrcnn_bbox_loss: 0.3521 - val_mrcnn_mask_loss: 0.4160
# Epoch 8/100
# 146/146 [==============================] - 376s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.6325 - rpn_class_loss: 0.2110 - rpn_bbox_loss: 0.3549 - mrcnn_class_loss: 0.3705 - mrcnn_bbox_loss: 0.3053 - mrcnn_mask_loss: 0.3908 - val_loss: 2.0929 - val_rpn_class_loss: 0.3303 - val_rpn_bbox_loss: 0.5082 - val_mrcnn_class_loss: 0.4979 - val_mrcnn_bbox_loss: 0.3648 - val_mrcnn_mask_loss: 0.3917
# Epoch 9/100
# 146/146 [==============================] - 383s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.5463 - rpn_class_loss: 0.1876 - rpn_bbox_loss: 0.3304 - mrcnn_class_loss: 0.3604 - mrcnn_bbox_loss: 0.2882 - mrcnn_mask_loss: 0.3798 - val_loss: 2.1766 - val_rpn_class_loss: 0.3909 - val_rpn_bbox_loss: 0.5722 - val_mrcnn_class_loss: 0.4478 - val_mrcnn_bbox_loss: 0.3414 - val_mrcnn_mask_loss: 0.4242
# Epoch 10/100
# 146/146 [==============================] - 362s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.5244 - rpn_class_loss: 0.1880 - rpn_bbox_loss: 0.3315 - mrcnn_class_loss: 0.3559 - mrcnn_bbox_loss: 0.2773 - mrcnn_mask_loss: 0.3717 - val_loss: 2.0837 - val_rpn_class_loss: 0.3874 - val_rpn_bbox_loss: 0.5158 - val_mrcnn_class_loss: 0.4565 - val_mrcnn_bbox_loss: 0.3296 - val_mrcnn_mask_loss: 0.3945
# Epoch 11/100
# 146/146 [==============================] - 359s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.4592 - rpn_class_loss: 0.1779 - rpn_bbox_loss: 0.3054 - mrcnn_class_loss: 0.3339 - mrcnn_bbox_loss: 0.2740 - mrcnn_mask_loss: 0.3679 - val_loss: 1.9764 - val_rpn_class_loss: 0.3617 - val_rpn_bbox_loss: 0.4791 - val_mrcnn_class_loss: 0.4217 - val_mrcnn_bbox_loss: 0.3395 - val_mrcnn_mask_loss: 0.3743
# Epoch 12/100
# 146/146 [==============================] - 353s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.4866 - rpn_class_loss: 0.1855 - rpn_bbox_loss: 0.3214 - mrcnn_class_loss: 0.3368 - mrcnn_bbox_loss: 0.2785 - mrcnn_mask_loss: 0.3644 - val_loss: 2.2222 - val_rpn_class_loss: 0.5082 - val_rpn_bbox_loss: 0.4900 - val_mrcnn_class_loss: 0.4894 - val_mrcnn_bbox_loss: 0.3358 - val_mrcnn_mask_loss: 0.3989
# Epoch 13/100
# 146/146 [==============================] - 402s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.4696 - rpn_class_loss: 0.1830 - rpn_bbox_loss: 0.3235 - mrcnn_class_loss: 0.3353 - mrcnn_bbox_loss: 0.2691 - mrcnn_mask_loss: 0.3587 - val_loss: 2.1782 - val_rpn_class_loss: 0.4122 - val_rpn_bbox_loss: 0.5464 - val_mrcnn_class_loss: 0.4941 - val_mrcnn_bbox_loss: 0.3304 - val_mrcnn_mask_loss: 0.3951
# Epoch 14/100
# 146/146 [==============================] - 354s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.4193 - rpn_class_loss: 0.1719 - rpn_bbox_loss: 0.2928 - mrcnn_class_loss: 0.3398 - mrcnn_bbox_loss: 0.2590 - mrcnn_mask_loss: 0.3558 - val_loss: 2.0625 - val_rpn_class_loss: 0.3580 - val_rpn_bbox_loss: 0.4973 - val_mrcnn_class_loss: 0.5042 - val_mrcnn_bbox_loss: 0.3244 - val_mrcnn_mask_loss: 0.3785
# Epoch 15/100
# 146/146 [==============================] - 325s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.3764 - rpn_class_loss: 0.1658 - rpn_bbox_loss: 0.2948 - mrcnn_class_loss: 0.3188 - mrcnn_bbox_loss: 0.2489 - mrcnn_mask_loss: 0.3481 - val_loss: 2.0228 - val_rpn_class_loss: 0.3326 - val_rpn_bbox_loss: 0.5006 - val_mrcnn_class_loss: 0.4556 - val_mrcnn_bbox_loss: 0.3261 - val_mrcnn_mask_loss: 0.4078
# Epoch 16/100
# 146/146 [==============================] - 379s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.3879 - rpn_class_loss: 0.1646 - rpn_bbox_loss: 0.2907 - mrcnn_class_loss: 0.3309 - mrcnn_bbox_loss: 0.2509 - mrcnn_mask_loss: 0.3507 - val_loss: 1.9860 - val_rpn_class_loss: 0.3295 - val_rpn_bbox_loss: 0.5049 - val_mrcnn_class_loss: 0.4541 - val_mrcnn_bbox_loss: 0.3307 - val_mrcnn_mask_loss: 0.3669
# Epoch 17/100
# 146/146 [==============================] - 382s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.3205 - rpn_class_loss: 0.1591 - rpn_bbox_loss: 0.2678 - mrcnn_class_loss: 0.3098 - mrcnn_bbox_loss: 0.2420 - mrcnn_mask_loss: 0.3418 - val_loss: 1.9365 - val_rpn_class_loss: 0.3342 - val_rpn_bbox_loss: 0.4847 - val_mrcnn_class_loss: 0.4301 - val_mrcnn_bbox_loss: 0.3250 - val_mrcnn_mask_loss: 0.3625
# Epoch 18/100
# 146/146 [==============================] - 353s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.3291 - rpn_class_loss: 0.1654 - rpn_bbox_loss: 0.2730 - mrcnn_class_loss: 0.3138 - mrcnn_bbox_loss: 0.2391 - mrcnn_mask_loss: 0.3377 - val_loss: 1.9679 - val_rpn_class_loss: 0.3643 - val_rpn_bbox_loss: 0.4891 - val_mrcnn_class_loss: 0.4563 - val_mrcnn_bbox_loss: 0.2888 - val_mrcnn_mask_loss: 0.3692
# Epoch 19/100
# 146/146 [==============================] - 342s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.3201 - rpn_class_loss: 0.1611 - rpn_bbox_loss: 0.2816 - mrcnn_class_loss: 0.3065 - mrcnn_bbox_loss: 0.2350 - mrcnn_mask_loss: 0.3359 - val_loss: 1.9401 - val_rpn_class_loss: 0.3491 - val_rpn_bbox_loss: 0.4910 - val_mrcnn_class_loss: 0.4299 - val_mrcnn_bbox_loss: 0.3047 - val_mrcnn_mask_loss: 0.3654
# Epoch 20/100
# 146/146 [==============================] - 341s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.2662 - rpn_class_loss: 0.1387 - rpn_bbox_loss: 0.2569 - mrcnn_class_loss: 0.3042 - mrcnn_bbox_loss: 0.2294 - mrcnn_mask_loss: 0.3369 - val_loss: 2.3149 - val_rpn_class_loss: 0.5926 - val_rpn_bbox_loss: 0.5480 - val_mrcnn_class_loss: 0.4800 - val_mrcnn_bbox_loss: 0.3024 - val_mrcnn_mask_loss: 0.3917
# Epoch 21/100
# 146/146 [==============================] - 405s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.2642 - rpn_class_loss: 0.1469 - rpn_bbox_loss: 0.2622 - mrcnn_class_loss: 0.3004 - mrcnn_bbox_loss: 0.2249 - mrcnn_mask_loss: 0.3297 - val_loss: 1.9487 - val_rpn_class_loss: 0.3572 - val_rpn_bbox_loss: 0.4713 - val_mrcnn_class_loss: 0.4559 - val_mrcnn_bbox_loss: 0.3059 - val_mrcnn_mask_loss: 0.3584
# Epoch 22/100
# 146/146 [==============================] - 389s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.2378 - rpn_class_loss: 0.1417 - rpn_bbox_loss: 0.2536 - mrcnn_class_loss: 0.2937 - mrcnn_bbox_loss: 0.2172 - mrcnn_mask_loss: 0.3317 - val_loss: 1.8640 - val_rpn_class_loss: 0.3332 - val_rpn_bbox_loss: 0.4627 - val_mrcnn_class_loss: 0.4018 - val_mrcnn_bbox_loss: 0.3103 - val_mrcnn_mask_loss: 0.3560
# Epoch 23/100
# 146/146 [==============================] - 343s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.2377 - rpn_class_loss: 0.1487 - rpn_bbox_loss: 0.2523 - mrcnn_class_loss: 0.2967 - mrcnn_bbox_loss: 0.2169 - mrcnn_mask_loss: 0.3232 - val_loss: 1.9685 - val_rpn_class_loss: 0.3633 - val_rpn_bbox_loss: 0.5165 - val_mrcnn_class_loss: 0.4225 - val_mrcnn_bbox_loss: 0.3003 - val_mrcnn_mask_loss: 0.3658
# Epoch 24/100
# 146/146 [==============================] - 369s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.2054 - rpn_class_loss: 0.1435 - rpn_bbox_loss: 0.2511 - mrcnn_class_loss: 0.2848 - mrcnn_bbox_loss: 0.2090 - mrcnn_mask_loss: 0.3170 - val_loss: 1.9866 - val_rpn_class_loss: 0.3861 - val_rpn_bbox_loss: 0.5206 - val_mrcnn_class_loss: 0.4284 - val_mrcnn_bbox_loss: 0.2900 - val_mrcnn_mask_loss: 0.3614
# Epoch 25/100
# 146/146 [==============================] - 358s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.2127 - rpn_class_loss: 0.1445 - rpn_bbox_loss: 0.2521 - mrcnn_class_loss: 0.2867 - mrcnn_bbox_loss: 0.2130 - mrcnn_mask_loss: 0.3162 - val_loss: 2.0746 - val_rpn_class_loss: 0.3630 - val_rpn_bbox_loss: 0.6016 - val_mrcnn_class_loss: 0.4481 - val_mrcnn_bbox_loss: 0.2935 - val_mrcnn_mask_loss: 0.3684
# Epoch 26/100
# 146/146 [==============================] - 403s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.1829 - rpn_class_loss: 0.1388 - rpn_bbox_loss: 0.2386 - mrcnn_class_loss: 0.2869 - mrcnn_bbox_loss: 0.2049 - mrcnn_mask_loss: 0.3137 - val_loss: 1.9239 - val_rpn_class_loss: 0.3661 - val_rpn_bbox_loss: 0.4914 - val_mrcnn_class_loss: 0.4414 - val_mrcnn_bbox_loss: 0.2745 - val_mrcnn_mask_loss: 0.3506
# Epoch 27/100
# 146/146 [==============================] - 348s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.1768 - rpn_class_loss: 0.1345 - rpn_bbox_loss: 0.2327 - mrcnn_class_loss: 0.2880 - mrcnn_bbox_loss: 0.2089 - mrcnn_mask_loss: 0.3127 - val_loss: 1.9616 - val_rpn_class_loss: 0.3519 - val_rpn_bbox_loss: 0.5137 - val_mrcnn_class_loss: 0.4268 - val_mrcnn_bbox_loss: 0.2799 - val_mrcnn_mask_loss: 0.3893
# Epoch 28/100
# 146/146 [==============================] - 349s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.1842 - rpn_class_loss: 0.1335 - rpn_bbox_loss: 0.2438 - mrcnn_class_loss: 0.2867 - mrcnn_bbox_loss: 0.2077 - mrcnn_mask_loss: 0.3125 - val_loss: 2.0542 - val_rpn_class_loss: 0.5084 - val_rpn_bbox_loss: 0.4839 - val_mrcnn_class_loss: 0.4302 - val_mrcnn_bbox_loss: 0.2846 - val_mrcnn_mask_loss: 0.3471
# Epoch 29/100
# 146/146 [==============================] - 388s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.1713 - rpn_class_loss: 0.1364 - rpn_bbox_loss: 0.2390 - mrcnn_class_loss: 0.2810 - mrcnn_bbox_loss: 0.2044 - mrcnn_mask_loss: 0.3103 - val_loss: 1.9596 - val_rpn_class_loss: 0.3641 - val_rpn_bbox_loss: 0.5055 - val_mrcnn_class_loss: 0.4553 - val_mrcnn_bbox_loss: 0.2805 - val_mrcnn_mask_loss: 0.3542
# Epoch 30/100
# 146/146 [==============================] - 390s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.1166 - rpn_class_loss: 0.1223 - rpn_bbox_loss: 0.2231 - mrcnn_class_loss: 0.2744 - mrcnn_bbox_loss: 0.1934 - mrcnn_mask_loss: 0.3035 - val_loss: 1.8635 - val_rpn_class_loss: 0.3335 - val_rpn_bbox_loss: 0.4733 - val_mrcnn_class_loss: 0.4085 - val_mrcnn_bbox_loss: 0.2940 - val_mrcnn_mask_loss: 0.3542
# Epoch 31/100
# 146/146 [==============================] - 363s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.1395 - rpn_class_loss: 0.1278 - rpn_bbox_loss: 0.2308 - mrcnn_class_loss: 0.2781 - mrcnn_bbox_loss: 0.1956 - mrcnn_mask_loss: 0.3072 - val_loss: 1.9352 - val_rpn_class_loss: 0.3591 - val_rpn_bbox_loss: 0.5199 - val_mrcnn_class_loss: 0.4278 - val_mrcnn_bbox_loss: 0.2756 - val_mrcnn_mask_loss: 0.3528
# Epoch 32/100
# 146/146 [==============================] - 359s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.1066 - rpn_class_loss: 0.1241 - rpn_bbox_loss: 0.2269 - mrcnn_class_loss: 0.2686 - mrcnn_bbox_loss: 0.1877 - mrcnn_mask_loss: 0.2994 - val_loss: 1.8747 - val_rpn_class_loss: 0.3296 - val_rpn_bbox_loss: 0.4721 - val_mrcnn_class_loss: 0.4318 - val_mrcnn_bbox_loss: 0.2844 - val_mrcnn_mask_loss: 0.3568
# Epoch 33/100
# 146/146 [==============================] - 360s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.1330 - rpn_class_loss: 0.1333 - rpn_bbox_loss: 0.2311 - mrcnn_class_loss: 0.2713 - mrcnn_bbox_loss: 0.1922 - mrcnn_mask_loss: 0.3051 - val_loss: 1.8355 - val_rpn_class_loss: 0.3417 - val_rpn_bbox_loss: 0.4647 - val_mrcnn_class_loss: 0.4047 - val_mrcnn_bbox_loss: 0.2732 - val_mrcnn_mask_loss: 0.3511
# Epoch 34/100
# 146/146 [==============================] - 390s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.0925 - rpn_class_loss: 0.1209 - rpn_bbox_loss: 0.2152 - mrcnn_class_loss: 0.2673 - mrcnn_bbox_loss: 0.1891 - mrcnn_mask_loss: 0.3000 - val_loss: 1.9630 - val_rpn_class_loss: 0.4330 - val_rpn_bbox_loss: 0.5101 - val_mrcnn_class_loss: 0.4005 - val_mrcnn_bbox_loss: 0.2686 - val_mrcnn_mask_loss: 0.3508
# Epoch 35/100
# 146/146 [==============================] - 376s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.0524 - rpn_class_loss: 0.1190 - rpn_bbox_loss: 0.2054 - mrcnn_class_loss: 0.2532 - mrcnn_bbox_loss: 0.1812 - mrcnn_mask_loss: 0.2936 - val_loss: 1.9157 - val_rpn_class_loss: 0.3845 - val_rpn_bbox_loss: 0.4900 - val_mrcnn_class_loss: 0.4302 - val_mrcnn_bbox_loss: 0.2764 - val_mrcnn_mask_loss: 0.3346
# Epoch 36/100
# 146/146 [==============================] - 381s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.0941 - rpn_class_loss: 0.1245 - rpn_bbox_loss: 0.2225 - mrcnn_class_loss: 0.2660 - mrcnn_bbox_loss: 0.1842 - mrcnn_mask_loss: 0.2969 - val_loss: 1.9058 - val_rpn_class_loss: 0.3404 - val_rpn_bbox_loss: 0.5015 - val_mrcnn_class_loss: 0.4347 - val_mrcnn_bbox_loss: 0.2855 - val_mrcnn_mask_loss: 0.3438
# Epoch 37/100
# 146/146 [==============================] - 373s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.0273 - rpn_class_loss: 0.1076 - rpn_bbox_loss: 0.2019 - mrcnn_class_loss: 0.2535 - mrcnn_bbox_loss: 0.1767 - mrcnn_mask_loss: 0.2876 - val_loss: 1.8623 - val_rpn_class_loss: 0.3610 - val_rpn_bbox_loss: 0.4846 - val_mrcnn_class_loss: 0.3964 - val_mrcnn_bbox_loss: 0.2836 - val_mrcnn_mask_loss: 0.3367
# Epoch 38/100
# 146/146 [==============================] - 402s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.0712 - rpn_class_loss: 0.1151 - rpn_bbox_loss: 0.2212 - mrcnn_class_loss: 0.2549 - mrcnn_bbox_loss: 0.1837 - mrcnn_mask_loss: 0.2963 - val_loss: 1.9154 - val_rpn_class_loss: 0.3433 - val_rpn_bbox_loss: 0.5064 - val_mrcnn_class_loss: 0.4319 - val_mrcnn_bbox_loss: 0.2856 - val_mrcnn_mask_loss: 0.3482
# Epoch 39/100
# 146/146 [==============================] - 343s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.0345 - rpn_class_loss: 0.1144 - rpn_bbox_loss: 0.2064 - mrcnn_class_loss: 0.2486 - mrcnn_bbox_loss: 0.1746 - mrcnn_mask_loss: 0.2905 - val_loss: 1.9430 - val_rpn_class_loss: 0.3882 - val_rpn_bbox_loss: 0.5175 - val_mrcnn_class_loss: 0.4293 - val_mrcnn_bbox_loss: 0.2657 - val_mrcnn_mask_loss: 0.3423
# Epoch 40/100
# 146/146 [==============================] - 355s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 1.0645 - rpn_class_loss: 0.1194 - rpn_bbox_loss: 0.2129 - mrcnn_class_loss: 0.2587 - mrcnn_bbox_loss: 0.1796 - mrcnn_mask_loss: 0.2939 - val_loss: 1.7731 - val_rpn_class_loss: 0.3587 - val_rpn_bbox_loss: 0.3990 - val_mrcnn_class_loss: 0.4377 - val_mrcnn_bbox_loss: 0.2604 - val_mrcnn_mask_loss: 0.3174
# Epoch 41/100
# 146/146 [==============================] - 365s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.9978 - rpn_class_loss: 0.1028 - rpn_bbox_loss: 0.2020 - mrcnn_class_loss: 0.2429 - mrcnn_bbox_loss: 0.1664 - mrcnn_mask_loss: 0.2837 - val_loss: 2.1034 - val_rpn_class_loss: 0.4598 - val_rpn_bbox_loss: 0.5451 - val_mrcnn_class_loss: 0.4415 - val_mrcnn_bbox_loss: 0.2911 - val_mrcnn_mask_loss: 0.3659
# Epoch 42/100
# 146/146 [==============================] - 370s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.9681 - rpn_class_loss: 0.0999 - rpn_bbox_loss: 0.1799 - mrcnn_class_loss: 0.2392 - mrcnn_bbox_loss: 0.1658 - mrcnn_mask_loss: 0.2833 - val_loss: 2.1679 - val_rpn_class_loss: 0.5510 - val_rpn_bbox_loss: 0.4923 - val_mrcnn_class_loss: 0.5197 - val_mrcnn_bbox_loss: 0.2626 - val_mrcnn_mask_loss: 0.3421
# Epoch 43/100
# 146/146 [==============================] - 391s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.9770 - rpn_class_loss: 0.1045 - rpn_bbox_loss: 0.1894 - mrcnn_class_loss: 0.2376 - mrcnn_bbox_loss: 0.1652 - mrcnn_mask_loss: 0.2803 - val_loss: 1.9637 - val_rpn_class_loss: 0.3979 - val_rpn_bbox_loss: 0.5441 - val_mrcnn_class_loss: 0.4144 - val_mrcnn_bbox_loss: 0.2629 - val_mrcnn_mask_loss: 0.3445
# Epoch 44/100
# 146/146 [==============================] - 357s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.9700 - rpn_class_loss: 0.1024 - rpn_bbox_loss: 0.1866 - mrcnn_class_loss: 0.2415 - mrcnn_bbox_loss: 0.1631 - mrcnn_mask_loss: 0.2764 - val_loss: 1.8729 - val_rpn_class_loss: 0.4126 - val_rpn_bbox_loss: 0.4725 - val_mrcnn_class_loss: 0.4125 - val_mrcnn_bbox_loss: 0.2503 - val_mrcnn_mask_loss: 0.3249
# Epoch 45/100
# 146/146 [==============================] - 339s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.9779 - rpn_class_loss: 0.1067 - rpn_bbox_loss: 0.1852 - mrcnn_class_loss: 0.2388 - mrcnn_bbox_loss: 0.1643 - mrcnn_mask_loss: 0.2830 - val_loss: 1.7623 - val_rpn_class_loss: 0.3660 - val_rpn_bbox_loss: 0.4290 - val_mrcnn_class_loss: 0.3919 - val_mrcnn_bbox_loss: 0.2575 - val_mrcnn_mask_loss: 0.3179
# Epoch 46/100
# 146/146 [==============================] - 347s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.9507 - rpn_class_loss: 0.0969 - rpn_bbox_loss: 0.1779 - mrcnn_class_loss: 0.2283 - mrcnn_bbox_loss: 0.1681 - mrcnn_mask_loss: 0.2794 - val_loss: 1.8917 - val_rpn_class_loss: 0.4679 - val_rpn_bbox_loss: 0.4676 - val_mrcnn_class_loss: 0.4067 - val_mrcnn_bbox_loss: 0.2348 - val_mrcnn_mask_loss: 0.3147
# Epoch 47/100
# 146/146 [==============================] - 397s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.9808 - rpn_class_loss: 0.1064 - rpn_bbox_loss: 0.1888 - mrcnn_class_loss: 0.2419 - mrcnn_bbox_loss: 0.1652 - mrcnn_mask_loss: 0.2784 - val_loss: 1.8176 - val_rpn_class_loss: 0.3711 - val_rpn_bbox_loss: 0.4440 - val_mrcnn_class_loss: 0.4238 - val_mrcnn_bbox_loss: 0.2427 - val_mrcnn_mask_loss: 0.3360
# Epoch 48/100
# 146/146 [==============================] - 343s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.9221 - rpn_class_loss: 0.0926 - rpn_bbox_loss: 0.1775 - mrcnn_class_loss: 0.2232 - mrcnn_bbox_loss: 0.1554 - mrcnn_mask_loss: 0.2735 - val_loss: 1.8839 - val_rpn_class_loss: 0.3784 - val_rpn_bbox_loss: 0.4977 - val_mrcnn_class_loss: 0.4151 - val_mrcnn_bbox_loss: 0.2613 - val_mrcnn_mask_loss: 0.3313
# Epoch 49/100
# 146/146 [==============================] - 374s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 1.0113 - rpn_class_loss: 0.1117 - rpn_bbox_loss: 0.1966 - mrcnn_class_loss: 0.2539 - mrcnn_bbox_loss: 0.1693 - mrcnn_mask_loss: 0.2799 - val_loss: 1.8111 - val_rpn_class_loss: 0.3158 - val_rpn_bbox_loss: 0.4932 - val_mrcnn_class_loss: 0.3788 - val_mrcnn_bbox_loss: 0.2797 - val_mrcnn_mask_loss: 0.3435
# Epoch 50/100
# 146/146 [==============================] - 388s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.9349 - rpn_class_loss: 0.1009 - rpn_bbox_loss: 0.1794 - mrcnn_class_loss: 0.2291 - mrcnn_bbox_loss: 0.1555 - mrcnn_mask_loss: 0.2700 - val_loss: 2.0322 - val_rpn_class_loss: 0.4892 - val_rpn_bbox_loss: 0.5033 - val_mrcnn_class_loss: 0.4221 - val_mrcnn_bbox_loss: 0.2767 - val_mrcnn_mask_loss: 0.3409
# Epoch 51/100
# 146/146 [==============================] - 404s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.9134 - rpn_class_loss: 0.0937 - rpn_bbox_loss: 0.1634 - mrcnn_class_loss: 0.2321 - mrcnn_bbox_loss: 0.1532 - mrcnn_mask_loss: 0.2710 - val_loss: 1.8577 - val_rpn_class_loss: 0.3757 - val_rpn_bbox_loss: 0.4836 - val_mrcnn_class_loss: 0.4184 - val_mrcnn_bbox_loss: 0.2548 - val_mrcnn_mask_loss: 0.3252
# Epoch 52/100
# 146/146 [==============================] - 351s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.8933 - rpn_class_loss: 0.0957 - rpn_bbox_loss: 0.1719 - mrcnn_class_loss: 0.2129 - mrcnn_bbox_loss: 0.1484 - mrcnn_mask_loss: 0.2643 - val_loss: 1.9204 - val_rpn_class_loss: 0.5033 - val_rpn_bbox_loss: 0.4345 - val_mrcnn_class_loss: 0.4221 - val_mrcnn_bbox_loss: 0.2410 - val_mrcnn_mask_loss: 0.3195
# Epoch 53/100
# 146/146 [==============================] - 357s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.9126 - rpn_class_loss: 0.0910 - rpn_bbox_loss: 0.1739 - mrcnn_class_loss: 0.2260 - mrcnn_bbox_loss: 0.1534 - mrcnn_mask_loss: 0.2683 - val_loss: 1.7091 - val_rpn_class_loss: 0.2930 - val_rpn_bbox_loss: 0.4319 - val_mrcnn_class_loss: 0.3816 - val_mrcnn_bbox_loss: 0.2708 - val_mrcnn_mask_loss: 0.3318
# Epoch 54/100
# 146/146 [==============================] - 375s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.9690 - rpn_class_loss: 0.1058 - rpn_bbox_loss: 0.2019 - mrcnn_class_loss: 0.2302 - mrcnn_bbox_loss: 0.1589 - mrcnn_mask_loss: 0.2723 - val_loss: 1.6792 - val_rpn_class_loss: 0.3275 - val_rpn_bbox_loss: 0.4043 - val_mrcnn_class_loss: 0.3941 - val_mrcnn_bbox_loss: 0.2486 - val_mrcnn_mask_loss: 0.3047
# Epoch 55/100
# 146/146 [==============================] - 393s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.9231 - rpn_class_loss: 0.0911 - rpn_bbox_loss: 0.1850 - mrcnn_class_loss: 0.2256 - mrcnn_bbox_loss: 0.1550 - mrcnn_mask_loss: 0.2664 - val_loss: 1.8150 - val_rpn_class_loss: 0.3374 - val_rpn_bbox_loss: 0.4669 - val_mrcnn_class_loss: 0.4291 - val_mrcnn_bbox_loss: 0.2581 - val_mrcnn_mask_loss: 0.3235
# Epoch 56/100
# 146/146 [==============================] - 339s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.9129 - rpn_class_loss: 0.1014 - rpn_bbox_loss: 0.1761 - mrcnn_class_loss: 0.2204 - mrcnn_bbox_loss: 0.1496 - mrcnn_mask_loss: 0.2654 - val_loss: 1.6535 - val_rpn_class_loss: 0.3004 - val_rpn_bbox_loss: 0.4028 - val_mrcnn_class_loss: 0.3759 - val_mrcnn_bbox_loss: 0.2555 - val_mrcnn_mask_loss: 0.3190
# Epoch 57/100
# 146/146 [==============================] - 362s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.9116 - rpn_class_loss: 0.0949 - rpn_bbox_loss: 0.1763 - mrcnn_class_loss: 0.2242 - mrcnn_bbox_loss: 0.1496 - mrcnn_mask_loss: 0.2667 - val_loss: 1.8505 - val_rpn_class_loss: 0.4321 - val_rpn_bbox_loss: 0.4173 - val_mrcnn_class_loss: 0.4389 - val_mrcnn_bbox_loss: 0.2479 - val_mrcnn_mask_loss: 0.3144
# Epoch 58/100
# 146/146 [==============================] - 350s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.8821 - rpn_class_loss: 0.0891 - rpn_bbox_loss: 0.1698 - mrcnn_class_loss: 0.2152 - mrcnn_bbox_loss: 0.1440 - mrcnn_mask_loss: 0.2640 - val_loss: 1.7415 - val_rpn_class_loss: 0.3104 - val_rpn_bbox_loss: 0.4575 - val_mrcnn_class_loss: 0.3820 - val_mrcnn_bbox_loss: 0.2569 - val_mrcnn_mask_loss: 0.3348
# Epoch 59/100
# 146/146 [==============================] - 376s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.8525 - rpn_class_loss: 0.0805 - rpn_bbox_loss: 0.1518 - mrcnn_class_loss: 0.2149 - mrcnn_bbox_loss: 0.1417 - mrcnn_mask_loss: 0.2635 - val_loss: 1.7974 - val_rpn_class_loss: 0.3841 - val_rpn_bbox_loss: 0.3996 - val_mrcnn_class_loss: 0.4380 - val_mrcnn_bbox_loss: 0.2663 - val_mrcnn_mask_loss: 0.3094
# Epoch 60/100
# 146/146 [==============================] - 367s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.8671 - rpn_class_loss: 0.0863 - rpn_bbox_loss: 0.1610 - mrcnn_class_loss: 0.2168 - mrcnn_bbox_loss: 0.1427 - mrcnn_mask_loss: 0.2602 - val_loss: 1.9463 - val_rpn_class_loss: 0.4841 - val_rpn_bbox_loss: 0.4647 - val_mrcnn_class_loss: 0.4228 - val_mrcnn_bbox_loss: 0.2496 - val_mrcnn_mask_loss: 0.3251
# Epoch 61/100
# 146/146 [==============================] - 364s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.9003 - rpn_class_loss: 0.0889 - rpn_bbox_loss: 0.1730 - mrcnn_class_loss: 0.2252 - mrcnn_bbox_loss: 0.1486 - mrcnn_mask_loss: 0.2647 - val_loss: 1.8439 - val_rpn_class_loss: 0.3725 - val_rpn_bbox_loss: 0.4115 - val_mrcnn_class_loss: 0.4804 - val_mrcnn_bbox_loss: 0.2682 - val_mrcnn_mask_loss: 0.3113
# Epoch 62/100
# 146/146 [==============================] - 358s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.8399 - rpn_class_loss: 0.0768 - rpn_bbox_loss: 0.1513 - mrcnn_class_loss: 0.2127 - mrcnn_bbox_loss: 0.1383 - mrcnn_mask_loss: 0.2608 - val_loss: 1.7106 - val_rpn_class_loss: 0.3313 - val_rpn_bbox_loss: 0.4108 - val_mrcnn_class_loss: 0.3950 - val_mrcnn_bbox_loss: 0.2519 - val_mrcnn_mask_loss: 0.3214
# Epoch 63/100
# 146/146 [==============================] - 371s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.8113 - rpn_class_loss: 0.0741 - rpn_bbox_loss: 0.1455 - mrcnn_class_loss: 0.1975 - mrcnn_bbox_loss: 0.1356 - mrcnn_mask_loss: 0.2587 - val_loss: 1.9243 - val_rpn_class_loss: 0.4339 - val_rpn_bbox_loss: 0.4821 - val_mrcnn_class_loss: 0.4312 - val_mrcnn_bbox_loss: 0.2460 - val_mrcnn_mask_loss: 0.3310
# Epoch 64/100
# 146/146 [==============================] - 367s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.8134 - rpn_class_loss: 0.0737 - rpn_bbox_loss: 0.1515 - mrcnn_class_loss: 0.2007 - mrcnn_bbox_loss: 0.1328 - mrcnn_mask_loss: 0.2547 - val_loss: 1.7272 - val_rpn_class_loss: 0.3160 - val_rpn_bbox_loss: 0.4234 - val_mrcnn_class_loss: 0.4044 - val_mrcnn_bbox_loss: 0.2563 - val_mrcnn_mask_loss: 0.3271
# Epoch 65/100
# 146/146 [==============================] - 360s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.8412 - rpn_class_loss: 0.0815 - rpn_bbox_loss: 0.1662 - mrcnn_class_loss: 0.2012 - mrcnn_bbox_loss: 0.1359 - mrcnn_mask_loss: 0.2564 - val_loss: 1.8884 - val_rpn_class_loss: 0.4183 - val_rpn_bbox_loss: 0.4742 - val_mrcnn_class_loss: 0.3916 - val_mrcnn_bbox_loss: 0.2587 - val_mrcnn_mask_loss: 0.3456
# Epoch 66/100
# 146/146 [==============================] - 364s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.8229 - rpn_class_loss: 0.0773 - rpn_bbox_loss: 0.1483 - mrcnn_class_loss: 0.2106 - mrcnn_bbox_loss: 0.1322 - mrcnn_mask_loss: 0.2545 - val_loss: 1.9007 - val_rpn_class_loss: 0.4026 - val_rpn_bbox_loss: 0.4958 - val_mrcnn_class_loss: 0.4125 - val_mrcnn_bbox_loss: 0.2552 - val_mrcnn_mask_loss: 0.3346
# Epoch 67/100
# 146/146 [==============================] - 386s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.8239 - rpn_class_loss: 0.0800 - rpn_bbox_loss: 0.1489 - mrcnn_class_loss: 0.2055 - mrcnn_bbox_loss: 0.1333 - mrcnn_mask_loss: 0.2561 - val_loss: 1.8290 - val_rpn_class_loss: 0.3916 - val_rpn_bbox_loss: 0.4429 - val_mrcnn_class_loss: 0.4128 - val_mrcnn_bbox_loss: 0.2567 - val_mrcnn_mask_loss: 0.3251
# Epoch 68/100
# 146/146 [==============================] - 421s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.8543 - rpn_class_loss: 0.0772 - rpn_bbox_loss: 0.1637 - mrcnn_class_loss: 0.2144 - mrcnn_bbox_loss: 0.1393 - mrcnn_mask_loss: 0.2597 - val_loss: 1.9320 - val_rpn_class_loss: 0.4159 - val_rpn_bbox_loss: 0.4846 - val_mrcnn_class_loss: 0.4594 - val_mrcnn_bbox_loss: 0.2393 - val_mrcnn_mask_loss: 0.3329
# Epoch 69/100
# 146/146 [==============================] - 364s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.8256 - rpn_class_loss: 0.0761 - rpn_bbox_loss: 0.1540 - mrcnn_class_loss: 0.2061 - mrcnn_bbox_loss: 0.1344 - mrcnn_mask_loss: 0.2549 - val_loss: 2.1184 - val_rpn_class_loss: 0.5824 - val_rpn_bbox_loss: 0.4559 - val_mrcnn_class_loss: 0.4952 - val_mrcnn_bbox_loss: 0.2644 - val_mrcnn_mask_loss: 0.3205
# Epoch 70/100
# 146/146 [==============================] - 388s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.8271 - rpn_class_loss: 0.0811 - rpn_bbox_loss: 0.1511 - mrcnn_class_loss: 0.2002 - mrcnn_bbox_loss: 0.1360 - mrcnn_mask_loss: 0.2586 - val_loss: 1.7496 - val_rpn_class_loss: 0.3356 - val_rpn_bbox_loss: 0.4077 - val_mrcnn_class_loss: 0.4350 - val_mrcnn_bbox_loss: 0.2576 - val_mrcnn_mask_loss: 0.3136
# Epoch 71/100
# 146/146 [==============================] - 364s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.8063 - rpn_class_loss: 0.0752 - rpn_bbox_loss: 0.1523 - mrcnn_class_loss: 0.1937 - mrcnn_bbox_loss: 0.1321 - mrcnn_mask_loss: 0.2529 - val_loss: 1.9446 - val_rpn_class_loss: 0.5022 - val_rpn_bbox_loss: 0.4430 - val_mrcnn_class_loss: 0.4373 - val_mrcnn_bbox_loss: 0.2507 - val_mrcnn_mask_loss: 0.3113
# Epoch 72/100
# 146/146 [==============================] - 396s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.7696 - rpn_class_loss: 0.0713 - rpn_bbox_loss: 0.1394 - mrcnn_class_loss: 0.1857 - mrcnn_bbox_loss: 0.1253 - mrcnn_mask_loss: 0.2478 - val_loss: 1.7875 - val_rpn_class_loss: 0.3921 - val_rpn_bbox_loss: 0.4011 - val_mrcnn_class_loss: 0.4403 - val_mrcnn_bbox_loss: 0.2469 - val_mrcnn_mask_loss: 0.3070
# Epoch 73/100
# 146/146 [==============================] - 349s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.8141 - rpn_class_loss: 0.0690 - rpn_bbox_loss: 0.1556 - mrcnn_class_loss: 0.2036 - mrcnn_bbox_loss: 0.1332 - mrcnn_mask_loss: 0.2527 - val_loss: 1.8012 - val_rpn_class_loss: 0.3955 - val_rpn_bbox_loss: 0.4131 - val_mrcnn_class_loss: 0.4095 - val_mrcnn_bbox_loss: 0.2609 - val_mrcnn_mask_loss: 0.3222
# Epoch 74/100
# 146/146 [==============================] - 347s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.7753 - rpn_class_loss: 0.0726 - rpn_bbox_loss: 0.1419 - mrcnn_class_loss: 0.1883 - mrcnn_bbox_loss: 0.1249 - mrcnn_mask_loss: 0.2477 - val_loss: 1.9625 - val_rpn_class_loss: 0.4842 - val_rpn_bbox_loss: 0.3988 - val_mrcnn_class_loss: 0.5166 - val_mrcnn_bbox_loss: 0.2547 - val_mrcnn_mask_loss: 0.3082
# Epoch 75/100
# 146/146 [==============================] - 367s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.8017 - rpn_class_loss: 0.0721 - rpn_bbox_loss: 0.1475 - mrcnn_class_loss: 0.2009 - mrcnn_bbox_loss: 0.1300 - mrcnn_mask_loss: 0.2512 - val_loss: 1.6935 - val_rpn_class_loss: 0.3197 - val_rpn_bbox_loss: 0.4292 - val_mrcnn_class_loss: 0.3956 - val_mrcnn_bbox_loss: 0.2407 - val_mrcnn_mask_loss: 0.3083
# Epoch 76/100
# 146/146 [==============================] - 369s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.7848 - rpn_class_loss: 0.0719 - rpn_bbox_loss: 0.1462 - mrcnn_class_loss: 0.1942 - mrcnn_bbox_loss: 0.1264 - mrcnn_mask_loss: 0.2462 - val_loss: 1.8696 - val_rpn_class_loss: 0.4743 - val_rpn_bbox_loss: 0.4187 - val_mrcnn_class_loss: 0.4208 - val_mrcnn_bbox_loss: 0.2454 - val_mrcnn_mask_loss: 0.3104
# Epoch 77/100
# 146/146 [==============================] - 351s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.7932 - rpn_class_loss: 0.0829 - rpn_bbox_loss: 0.1466 - mrcnn_class_loss: 0.1923 - mrcnn_bbox_loss: 0.1248 - mrcnn_mask_loss: 0.2466 - val_loss: 1.8016 - val_rpn_class_loss: 0.3653 - val_rpn_bbox_loss: 0.4152 - val_mrcnn_class_loss: 0.4605 - val_mrcnn_bbox_loss: 0.2516 - val_mrcnn_mask_loss: 0.3091
# Epoch 78/100
# 146/146 [==============================] - 389s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.7591 - rpn_class_loss: 0.0690 - rpn_bbox_loss: 0.1383 - mrcnn_class_loss: 0.1834 - mrcnn_bbox_loss: 0.1226 - mrcnn_mask_loss: 0.2458 - val_loss: 2.0431 - val_rpn_class_loss: 0.5602 - val_rpn_bbox_loss: 0.4621 - val_mrcnn_class_loss: 0.4657 - val_mrcnn_bbox_loss: 0.2421 - val_mrcnn_mask_loss: 0.3130
# Epoch 79/100
# 146/146 [==============================] - 351s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.7414 - rpn_class_loss: 0.0650 - rpn_bbox_loss: 0.1276 - mrcnn_class_loss: 0.1869 - mrcnn_bbox_loss: 0.1183 - mrcnn_mask_loss: 0.2434 - val_loss: 1.7732 - val_rpn_class_loss: 0.3381 - val_rpn_bbox_loss: 0.4890 - val_mrcnn_class_loss: 0.4088 - val_mrcnn_bbox_loss: 0.2335 - val_mrcnn_mask_loss: 0.3038
# Epoch 80/100
# 146/146 [==============================] - 366s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.7224 - rpn_class_loss: 0.0628 - rpn_bbox_loss: 0.1241 - mrcnn_class_loss: 0.1800 - mrcnn_bbox_loss: 0.1135 - mrcnn_mask_loss: 0.2420 - val_loss: 2.0703 - val_rpn_class_loss: 0.5088 - val_rpn_bbox_loss: 0.4713 - val_mrcnn_class_loss: 0.5092 - val_mrcnn_bbox_loss: 0.2560 - val_mrcnn_mask_loss: 0.3250
# Epoch 81/100
# 146/146 [==============================] - 405s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.7784 - rpn_class_loss: 0.0708 - rpn_bbox_loss: 0.1436 - mrcnn_class_loss: 0.1890 - mrcnn_bbox_loss: 0.1247 - mrcnn_mask_loss: 0.2502 - val_loss: 1.7717 - val_rpn_class_loss: 0.3377 - val_rpn_bbox_loss: 0.4621 - val_mrcnn_class_loss: 0.4012 - val_mrcnn_bbox_loss: 0.2483 - val_mrcnn_mask_loss: 0.3223
# Epoch 82/100
# 146/146 [==============================] - 387s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.7957 - rpn_class_loss: 0.0754 - rpn_bbox_loss: 0.1466 - mrcnn_class_loss: 0.1972 - mrcnn_bbox_loss: 0.1259 - mrcnn_mask_loss: 0.2505 - val_loss: 1.7661 - val_rpn_class_loss: 0.3991 - val_rpn_bbox_loss: 0.4223 - val_mrcnn_class_loss: 0.4183 - val_mrcnn_bbox_loss: 0.2263 - val_mrcnn_mask_loss: 0.3000
# Epoch 83/100
# 146/146 [==============================] - 380s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.7344 - rpn_class_loss: 0.0597 - rpn_bbox_loss: 0.1274 - mrcnn_class_loss: 0.1805 - mrcnn_bbox_loss: 0.1196 - mrcnn_mask_loss: 0.2471 - val_loss: 1.8282 - val_rpn_class_loss: 0.3614 - val_rpn_bbox_loss: 0.4569 - val_mrcnn_class_loss: 0.4548 - val_mrcnn_bbox_loss: 0.2430 - val_mrcnn_mask_loss: 0.3120
# Epoch 84/100
# 146/146 [==============================] - 385s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.7159 - rpn_class_loss: 0.0649 - rpn_bbox_loss: 0.1278 - mrcnn_class_loss: 0.1735 - mrcnn_bbox_loss: 0.1128 - mrcnn_mask_loss: 0.2370 - val_loss: 2.0997 - val_rpn_class_loss: 0.5521 - val_rpn_bbox_loss: 0.4766 - val_mrcnn_class_loss: 0.4791 - val_mrcnn_bbox_loss: 0.2566 - val_mrcnn_mask_loss: 0.3354
# Epoch 85/100
# 146/146 [==============================] - 402s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.7060 - rpn_class_loss: 0.0594 - rpn_bbox_loss: 0.1236 - mrcnn_class_loss: 0.1740 - mrcnn_bbox_loss: 0.1137 - mrcnn_mask_loss: 0.2354 - val_loss: 1.9977 - val_rpn_class_loss: 0.5165 - val_rpn_bbox_loss: 0.4631 - val_mrcnn_class_loss: 0.4441 - val_mrcnn_bbox_loss: 0.2438 - val_mrcnn_mask_loss: 0.3303
# Epoch 86/100
# 146/146 [==============================] - 357s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.6991 - rpn_class_loss: 0.0558 - rpn_bbox_loss: 0.1187 - mrcnn_class_loss: 0.1778 - mrcnn_bbox_loss: 0.1123 - mrcnn_mask_loss: 0.2344 - val_loss: 1.8767 - val_rpn_class_loss: 0.3954 - val_rpn_bbox_loss: 0.4865 - val_mrcnn_class_loss: 0.4242 - val_mrcnn_bbox_loss: 0.2469 - val_mrcnn_mask_loss: 0.3237
# Epoch 87/100
# 146/146 [==============================] - 341s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.6831 - rpn_class_loss: 0.0523 - rpn_bbox_loss: 0.1123 - mrcnn_class_loss: 0.1702 - mrcnn_bbox_loss: 0.1103 - mrcnn_mask_loss: 0.2380 - val_loss: 1.9822 - val_rpn_class_loss: 0.5198 - val_rpn_bbox_loss: 0.4187 - val_mrcnn_class_loss: 0.4782 - val_mrcnn_bbox_loss: 0.2513 - val_mrcnn_mask_loss: 0.3141
# Epoch 88/100
# 146/146 [==============================] - 393s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.7019 - rpn_class_loss: 0.0538 - rpn_bbox_loss: 0.1219 - mrcnn_class_loss: 0.1745 - mrcnn_bbox_loss: 0.1146 - mrcnn_mask_loss: 0.2370 - val_loss: 1.8269 - val_rpn_class_loss: 0.4576 - val_rpn_bbox_loss: 0.4184 - val_mrcnn_class_loss: 0.4116 - val_mrcnn_bbox_loss: 0.2326 - val_mrcnn_mask_loss: 0.3067
# Epoch 89/100
# 146/146 [==============================] - 382s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.7158 - rpn_class_loss: 0.0625 - rpn_bbox_loss: 0.1298 - mrcnn_class_loss: 0.1687 - mrcnn_bbox_loss: 0.1164 - mrcnn_mask_loss: 0.2385 - val_loss: 2.0179 - val_rpn_class_loss: 0.5129 - val_rpn_bbox_loss: 0.5270 - val_mrcnn_class_loss: 0.4127 - val_mrcnn_bbox_loss: 0.2486 - val_mrcnn_mask_loss: 0.3168
# Epoch 90/100
# 146/146 [==============================] - 352s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.6956 - rpn_class_loss: 0.0584 - rpn_bbox_loss: 0.1278 - mrcnn_class_loss: 0.1648 - mrcnn_bbox_loss: 0.1099 - mrcnn_mask_loss: 0.2349 - val_loss: 1.9198 - val_rpn_class_loss: 0.4386 - val_rpn_bbox_loss: 0.4743 - val_mrcnn_class_loss: 0.4343 - val_mrcnn_bbox_loss: 0.2462 - val_mrcnn_mask_loss: 0.3264
# Epoch 91/100
# 146/146 [==============================] - 353s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.6979 - rpn_class_loss: 0.0528 - rpn_bbox_loss: 0.1227 - mrcnn_class_loss: 0.1694 - mrcnn_bbox_loss: 0.1130 - mrcnn_mask_loss: 0.2399 - val_loss: 2.0025 - val_rpn_class_loss: 0.4666 - val_rpn_bbox_loss: 0.5133 - val_mrcnn_class_loss: 0.4339 - val_mrcnn_bbox_loss: 0.2444 - val_mrcnn_mask_loss: 0.3443
# Epoch 92/100
# 146/146 [==============================] - 373s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.6935 - rpn_class_loss: 0.0540 - rpn_bbox_loss: 0.1221 - mrcnn_class_loss: 0.1691 - mrcnn_bbox_loss: 0.1131 - mrcnn_mask_loss: 0.2352 - val_loss: 1.7064 - val_rpn_class_loss: 0.3268 - val_rpn_bbox_loss: 0.4408 - val_mrcnn_class_loss: 0.3966 - val_mrcnn_bbox_loss: 0.2400 - val_mrcnn_mask_loss: 0.3022
# Epoch 93/100
# 146/146 [==============================] - 372s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.6739 - rpn_class_loss: 0.0508 - rpn_bbox_loss: 0.1146 - mrcnn_class_loss: 0.1697 - mrcnn_bbox_loss: 0.1067 - mrcnn_mask_loss: 0.2320 - val_loss: 1.8730 - val_rpn_class_loss: 0.3821 - val_rpn_bbox_loss: 0.5059 - val_mrcnn_class_loss: 0.4361 - val_mrcnn_bbox_loss: 0.2366 - val_mrcnn_mask_loss: 0.3124
# Epoch 94/100
# 146/146 [==============================] - 342s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.6619 - rpn_class_loss: 0.0464 - rpn_bbox_loss: 0.1095 - mrcnn_class_loss: 0.1667 - mrcnn_bbox_loss: 0.1070 - mrcnn_mask_loss: 0.2323 - val_loss: 2.1652 - val_rpn_class_loss: 0.6015 - val_rpn_bbox_loss: 0.4580 - val_mrcnn_class_loss: 0.5379 - val_mrcnn_bbox_loss: 0.2457 - val_mrcnn_mask_loss: 0.3220
# Epoch 95/100
# 146/146 [==============================] - 370s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.6942 - rpn_class_loss: 0.0541 - rpn_bbox_loss: 0.1252 - mrcnn_class_loss: 0.1699 - mrcnn_bbox_loss: 0.1107 - mrcnn_mask_loss: 0.2343 - val_loss: 1.9907 - val_rpn_class_loss: 0.5043 - val_rpn_bbox_loss: 0.4189 - val_mrcnn_class_loss: 0.4988 - val_mrcnn_bbox_loss: 0.2518 - val_mrcnn_mask_loss: 0.3170
# Epoch 96/100
# 146/146 [==============================] - 363s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.6485 - rpn_class_loss: 0.0515 - rpn_bbox_loss: 0.1123 - mrcnn_class_loss: 0.1576 - mrcnn_bbox_loss: 0.1013 - mrcnn_mask_loss: 0.2259 - val_loss: 1.7498 - val_rpn_class_loss: 0.3740 - val_rpn_bbox_loss: 0.3967 - val_mrcnn_class_loss: 0.4289 - val_mrcnn_bbox_loss: 0.2509 - val_mrcnn_mask_loss: 0.2993
# Epoch 97/100
# 146/146 [==============================] - 394s 3s/step - batch: 72.5000 - size: 2.0000 - loss: 0.6762 - rpn_class_loss: 0.0515 - rpn_bbox_loss: 0.1159 - mrcnn_class_loss: 0.1663 - mrcnn_bbox_loss: 0.1076 - mrcnn_mask_loss: 0.2349 - val_loss: 2.1203 - val_rpn_class_loss: 0.5951 - val_rpn_bbox_loss: 0.4670 - val_mrcnn_class_loss: 0.5045 - val_mrcnn_bbox_loss: 0.2400 - val_mrcnn_mask_loss: 0.3136
# Epoch 98/100
# 146/146 [==============================] - 349s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.6542 - rpn_class_loss: 0.0531 - rpn_bbox_loss: 0.1176 - mrcnn_class_loss: 0.1521 - mrcnn_bbox_loss: 0.1014 - mrcnn_mask_loss: 0.2300 - val_loss: 1.7816 - val_rpn_class_loss: 0.3699 - val_rpn_bbox_loss: 0.4309 - val_mrcnn_class_loss: 0.4239 - val_mrcnn_bbox_loss: 0.2453 - val_mrcnn_mask_loss: 0.3115
# Epoch 99/100
# 146/146 [==============================] - 357s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.6368 - rpn_class_loss: 0.0515 - rpn_bbox_loss: 0.1020 - mrcnn_class_loss: 0.1559 - mrcnn_bbox_loss: 0.1016 - mrcnn_mask_loss: 0.2258 - val_loss: 2.0192 - val_rpn_class_loss: 0.5235 - val_rpn_bbox_loss: 0.5001 - val_mrcnn_class_loss: 0.4446 - val_mrcnn_bbox_loss: 0.2335 - val_mrcnn_mask_loss: 0.3176
# Epoch 100/100
# 146/146 [==============================] - 355s 2s/step - batch: 72.5000 - size: 2.0000 - loss: 0.6267 - rpn_class_loss: 0.0498 - rpn_bbox_loss: 0.1040 - mrcnn_class_loss: 0.1542 - mrcnn_bbox_loss: 0.0962 - mrcnn_mask_loss: 0.2225 - val_loss: 2.1194 - val_rpn_class_loss: 0.6016 - val_rpn_bbox_loss: 0.4572 - val_mrcnn_class_loss: 0.5068 - val_mrcnn_bbox_loss: 0.2424 - val_mrcnn_mask_loss: 0.3113

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [raw]
# log_dir = "./logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# #tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, update_freq=1)

# %% [raw]
# log_dir = "./logs/fit/"

# %%
# %tensorboard --logdir arandano_cfg_test_6_2_20220918T1934
# Out:
# Reusing TensorBoard on port 6006 (pid 3280244), started 0:00:36 ago. (Use '!kill 3280244' to kill it.)
#       <iframe id="tensorboard-frame-314db4bc64ae225a" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-314db4bc64ae225a");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !kill 3280244
